# %%
# EOMs
# %reset
#import libraries
import sympy as sym
import numpy as np
import pickle as pickle

sym.init_printing()
from IPython.display import display #for pretty printing

# Symbols --------------------------------------------------
legs = ['A','B']
links = ['ull','lll','url','lrl']
bases = ['body','disc']
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
#Parameters
masses = {}
lengths = {}
inertias = {}

LL = sym.symbols('LL')
g = sym.symbols('g')
foot_angle = 136*(np.pi/180)

for leg in legs:
    for link in links:   
        masses.update({(link,leg): sym.symbols('m_{0}'.format(link+leg))})
        lengths.update({(link,leg): sym.symbols('l_{0}'.format(link+leg))})
        inertias.update({(link,leg): sym.symbols('In_{0}'.format(link+leg))})

for base in bases:
    masses.update({(base): sym.symbols('m_{0}'.format(base))})
    lengths.update({(base): sym.symbols('l_{0}'.format(base))})
    inertias.update({(base): sym.symbols('In_{0}'.format(base))})

#gen coordinates
x_body,y_body,th_body,th_disc = sym.symbols(['x_body','y_body','theta_{0}'.format('body'),'theta_{0}'.format('disc')])
dx_body,dy_body,dth_body, dth_disc = sym.symbols(['\dot{\\x}_{body}','\dot{\\y}_{body}','\dot{\\theta}_{body}','\dot{\\theta}_{disc}'])
ddx_body,ddy_body,ddth_body, ddth_disc = sym.symbols(['\ddot{\\x}_{body}','\ddot{\\y}_{body}','\ddot{\\theta}_{body}','\ddot{\\theta}_{disc}'])

th = {}
dth = {}
ddth = {}

for leg in legs:
    for link in links:
        th.update({(link,leg): sym.symbols('theta_{0}'.format(link+leg))}) 
        dth.update({(link,leg): sym.symbols('\dot{{\\theta}}_{{{0}}}'.format(link+leg))})
        ddth.update({(link,leg): sym.symbols('\ddot{{\\theta}}_{{{0}}}'.format(link+leg))})

# %%
q = sym.Matrix([x_body]+[y_body]+[th_body]+[th_disc]+[th[link,leg] for leg in legs for link in links])
dq = sym.Matrix([dx_body]+[dy_body]+[dth_body]+[dth_disc]+[dth[link,leg] for leg in legs for link in links])
ddq = sym.Matrix([ddx_body]+[ddy_body]+[ddth_body]+[ddth_disc]+[ddth[link,leg] for leg in legs for link in links])

# %%
q
# Out:
# ⎡x_body⎤
# ⎢      ⎥
# ⎢y_body⎥
# ⎢      ⎥
# ⎢θ_body⎥
# ⎢      ⎥
# ⎢θ_disc⎥
# ⎢      ⎥
# ⎢θ_ullA⎥
# ⎢      ⎥
# ⎢θ_lllA⎥
# ⎢      ⎥
# ⎢θ_urlA⎥
# ⎢      ⎥
# ⎢θ_lrlA⎥
# ⎢      ⎥
# ⎢θ_ullB⎥
# ⎢      ⎥
# ⎢θ_lllB⎥
# ⎢      ⎥
# ⎢θ_urlB⎥
# ⎢      ⎥
# ⎣θ_lrlB⎦

# %%
dq
# Out:
# ⎡  \dot{\x}_{body}  ⎤
# ⎢                   ⎥
# ⎢  \dot{\y}_{body}  ⎥
# ⎢                   ⎥
# ⎢\dot{\theta}_{body}⎥
# ⎢                   ⎥
# ⎢\dot{\theta}_{disc}⎥
# ⎢                   ⎥
# ⎢\dot{\theta}_{ullA}⎥
# ⎢                   ⎥
# ⎢\dot{\theta}_{lllA}⎥
# ⎢                   ⎥
# ⎢\dot{\theta}_{urlA}⎥
# ⎢                   ⎥
# ⎢\dot{\theta}_{lrlA}⎥
# ⎢                   ⎥
# ⎢\dot{\theta}_{ullB}⎥
# ⎢                   ⎥
# ⎢\dot{\theta}_{lllB}⎥
# ⎢                   ⎥
# ⎢\dot{\theta}_{urlB}⎥
# ⎢                   ⎥
# ⎣\dot{\theta}_{lrlB}⎦

# %%
ddq
# Out:
# ⎡  \ddot{\x}_{body}  ⎤
# ⎢                    ⎥
# ⎢  \ddot{\y}_{body}  ⎥
# ⎢                    ⎥
# ⎢\ddot{\theta}_{body}⎥
# ⎢                    ⎥
# ⎢\ddot{\theta}_{disc}⎥
# ⎢                    ⎥
# ⎢\ddot{\theta}_{ullA}⎥
# ⎢                    ⎥
# ⎢\ddot{\theta}_{lllA}⎥
# ⎢                    ⎥
# ⎢\ddot{\theta}_{urlA}⎥
# ⎢                    ⎥
# ⎢\ddot{\theta}_{lrlA}⎥
# ⎢                    ⎥
# ⎢\ddot{\theta}_{ullB}⎥
# ⎢                    ⎥
# ⎢\ddot{\theta}_{lllB}⎥
# ⎢                    ⎥
# ⎢\ddot{\theta}_{urlB}⎥
# ⎢                    ⎥
# ⎣\ddot{\theta}_{lrlB}⎦

# %%
''' Setup positions (to COM) and velocities'''

r_bases = {}

# position to COM of each link - where the mass is approximated to be
r_bases.update({'body': sym.Matrix([[x_body,
                                     y_body]]).transpose()})
r_bases.update({'disc': sym.Matrix([[x_body,
                                     y_body]]).transpose()})


# define absolute angles
abs_angles = {}
r_links = {}


for leg in legs:
    
    abs_angles.update({('LU',leg): th_body + th['ull',leg]})
    abs_angles.update({('LL',leg): th['lll',leg] - (np.pi - abs_angles['LU',leg])})
    abs_angles.update({('RU',leg): th_body + th['url',leg]})
    abs_angles.update({('RL',leg): th['lrl',leg] - (np.pi - abs_angles['RU',leg]) }) 
    abs_angles.update({('disc',leg): th_body + th_disc})
    
    r_links.update({('ull',leg): sym.Matrix([[x_body-LL/2*sym.cos(th_body)-lengths['ull',leg]/2*sym.cos(abs_angles['LU',leg]),
                                              y_body-LL/2*sym.sin(th_body)-lengths['ull',leg]/2*sym.sin(abs_angles['LU',leg])]]).transpose()})
    
    r_links.update({('lll',leg): sym.Matrix([[r_links['ull',leg][0]-0.5*lengths['ull',leg]*sym.cos(abs_angles['LU',leg])+lengths['lll',leg]/2*sym.cos(np.pi-abs_angles['LL',leg]),
                                              r_links['ull',leg][1]-0.5*lengths['ull',leg]*sym.sin(abs_angles['LU',leg])-lengths['lll',leg]/2*sym.sin(np.pi-abs_angles['LL',leg])]]).transpose()})
    
    r_links.update({('url',leg): sym.Matrix([[x_body+LL/2*sym.cos(th_body)+lengths['url',leg]/2*sym.cos(np.pi-abs_angles['RU',leg]),
                                              y_body+LL/2*sym.sin(th_body)-lengths['url',leg]/2*sym.sin(np.pi-abs_angles['RU',leg])]]).transpose()})
    
    r_links.update({('lrl',leg): sym.Matrix([[r_links['url',leg][0]+0.5*lengths['url',leg]*sym.cos(np.pi-abs_angles['RU',leg])-lengths['lrl',leg]/2*sym.cos(abs_angles['RL',leg]),
                                              r_links['url',leg][1]-0.5*lengths['url',leg]*sym.sin(np.pi-abs_angles['RU',leg])-lengths['lrl',leg]/2*sym.sin(abs_angles['RL',leg])]]).transpose()})

# %%
dr_bases = {}
dr_links = {}
w_links = {}
w_bases = {}

w_bases.update({'body': dth_body})
w_bases.update({'disc': dth_body+dth_disc})

for base in bases:
    dr_bases.update({base: r_bases[base].jacobian(q)*dq})

for leg in legs:
    
    w_links.update({('ull',leg): dth['ull',leg] + dth_body})
    w_links.update({('lll',leg): dth['ull',leg] + dth['lll',leg] + dth_body})
    w_links.update({('url',leg): dth['url',leg] + dth_body})
    w_links.update({('lrl',leg): dth['url',leg] + dth['lrl',leg] + dth_body})
    
    for link in links:
        dr_links.update({(link,leg): r_links[link,leg].jacobian(q)*dq})

# %%
T_bases = {}
T_links = {}
V_bases = {}
V_links = {}

# Kinetic Energy
T_bases.update({'body': 0.5*sym.Matrix([[masses['body'],masses['body']]])*sym.matrix_multiply_elementwise(dr_bases['body'],dr_bases['body']) + sym.Matrix([[0.5*w_bases['body']*w_bases['body']*inertias['body']]])})
T_bases.update({'disc': 0.5*sym.Matrix([[masses['disc'],masses['disc']]])*sym.matrix_multiply_elementwise(dr_bases['disc'],dr_bases['disc']) + sym.Matrix([[0.5*w_bases['disc']*w_bases['disc']*inertias['disc']]])})


# Potential Energy
for base in bases:
    V_bases.update({base: masses[base]*g*r_bases[base][1]})

for leg in legs:
    for link in links:
        T_links.update({(link,leg): 0.5*sym.Matrix([[masses[link,leg],masses[link,leg]]])*sym.matrix_multiply_elementwise(dr_links[link,leg],dr_links[link,leg]) + sym.Matrix([[0.5*w_links[link,leg]*w_links[link,leg]*inertias[link,leg]]])})
        V_links.update({(link,leg): masses[link,leg]*g*r_links[link,leg][1]})

Ttot = T_bases['body'] + T_bases['disc']
Vtot = V_bases['body'] + V_bases['disc']
    
for leg in legs:
    for link in links:
        Ttot = Ttot + T_links[link,leg] 
        Vtot = Vtot + V_links[link,leg] 
        
Ttot = Ttot[0]

# %%
# Manipulator Equation (M*ddq + C + G = Tau + Q)

# M Matrix
M = sym.zeros(len(q),len(q))

for i in range(len(q)):
    for j in range(len(q)):
        M[i,j] = sym.diff(sym.diff(Ttot,dq[i]),dq[j])

M = sym.simplify(M)

M_size = int(np.sqrt(len(M))) # assumes square matrix (len(M) = 4x4 = 16)

dM = sym.zeros(M_size,M_size)

for i in range(M_size):
    for j in range(M_size):
        dM[i,j] = sym.Matrix([M[i,j]]).jacobian(q)*dq

# C Matrix
C = dM*dq - (sym.Matrix([Ttot]).jacobian(q)).transpose() # 4x1 - 1x4^Transpose

# G Matrix
G = (sym.Matrix([Vtot]).jacobian(q)).transpose() # 4x1

tau = {}
lamda = {}
GRF = {}

connect_foot_position = {}

Jbn = {}
Jfoot = {}
lamda_GRF = {}
lamda_connect = {}

tau.update({('disc'): sym.symbols('tau_disc')})

Tau = sym.Matrix([[0],[0],[0],[tau['disc']]])

Q = sym.zeros(len(q),1)

for leg in legs:
    tau.update({('left',leg): sym.symbols('tau_left{0}'.format(leg))})
    tau.update({('right',leg): sym.symbols('tau_right{0}'.format(leg))})
    
    lamda.update({('x',leg): sym.symbols('lamda_x{0}'.format(leg))})
    lamda.update({('y',leg): sym.symbols('lamda_y{0}'.format(leg))})
    
    GRF.update({('x',leg): sym.symbols('GRF_x{0}'.format(leg))})
    GRF.update({('y',leg): sym.symbols('GRF_y{0}'.format(leg))})
    
    connect_foot_position.update({('left',leg): sym.Matrix([[r_links['lll',leg][0]+0.5*lengths['lll',leg]*sym.cos(np.pi-abs_angles['LL',leg])],
                                                       [r_links['lll',leg][1]-0.5*lengths['lll',leg]*sym.sin(np.pi-abs_angles['LL',leg])]]).transpose()})
    
    connect_foot_position.update({('right',leg): sym.Matrix([[r_links['lrl',leg][0]-0.5*lengths['lrl',leg]*sym.cos(abs_angles['RL',leg])],
                                                        [r_links['lrl',leg][1]-0.5*lengths['lrl',leg]*sym.sin(abs_angles['RL',leg])]]).transpose()})


    Jbn.update({('left',leg): connect_foot_position['left',leg].jacobian(q)})                    
    Jbn.update({('right',leg): connect_foot_position['right',leg].jacobian(q)})                    
    Jfoot.update({(leg): connect_foot_position['right',leg].jacobian(q)})                    
    lamda_GRF.update({(leg): sym.Matrix([[GRF['x',leg]],[GRF['y',leg]]])})
    
    lamda_connect.update({('left',leg): sym.Matrix([[-lamda['x',leg]],[-lamda['y',leg]]])})
    lamda_connect.update({('right',leg): sym.Matrix([[lamda['x',leg]],[lamda['y',leg]]])})
    
    Tau = Tau.col_join(sym.Matrix([[tau['left',leg]],[0],[tau['right',leg]],[0]]))
    
    Q = Q + (Jfoot[leg].transpose()*lamda_GRF[leg]) + (Jbn['left',leg].transpose()*lamda_connect['left',leg]) + (Jbn['right',leg].transpose()*lamda_connect['right',leg])
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-15cc511119e7>", line 10, in <module>
#     M = sym.simplify(M)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/simplify.py", line 592, in simplify
#     return _eval_simplify(**kwargs)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py", line 2485, in _eval_simplify
#     return MatrixOperations.simplify(self, **kwargs)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py", line 2375, in simplify
#     return self.applyfunc(lambda x: x.simplify(**kwargs))
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py", line 2026, in applyfunc
#     return self._eval_applyfunc(f)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py", line 1966, in _eval_applyfunc
#     out = self._new(self.rows, self.cols, [f(x) for x in self])
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py", line 1966, in <listcomp>
#     out = self._new(self.rows, self.cols, [f(x) for x in self])
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py", line 2375, in <lambda>
#     return self.applyfunc(lambda x: x.simplify(**kwargs))
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/core/basic.py", line 1675, in simplify
#     return simplify(self, **kwargs)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/simplify.py", line 696, in simplify
#     expr = trigsimp(expr, deep=True)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py", line 510, in trigsimp
#     return trigsimpfunc(expr)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py", line 503, in <lambda>
#     'matching': (lambda x: futrig(x)),
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py", line 1102, in futrig
#     e = bottom_up(e, _futrig)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/simplify.py", line 1198, in bottom_up
#     rv = F(rv)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py", line 1170, in _futrig
#     e = greedy(tree, objective=Lops)(e)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/strategies/core.py", line 111, in minrule
#     return min([rule(expr) for rule in rules], key=objective)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/strategies/core.py", line 111, in <listcomp>
#     return min([rule(expr) for rule in rules], key=objective)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/strategies/core.py", line 41, in chain_rl
#     expr = rule(expr)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py", line 1147, in <lambda>
#     lambda x: _eapply(factor, x, trigs),
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py", line 1195, in _eapply
#     return func(e)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polytools.py", line 6390, in factor
#     return _generic_factor(f, gens, args, method='factor')
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polytools.py", line 6062, in _generic_factor
#     return _symbolic_factor(sympify(expr), opt, method)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polytools.py", line 6002, in _symbolic_factor
#     coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polytools.py", line 5967, in _symbolic_factor_list
#     _coeff, _factors = func()
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polytools.py", line 3336, in factor_list
#     coeff, factors = f.rep.factor_list()
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polyclasses.py", line 795, in factor_list
#     coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/factortools.py", line 1411, in dmp_factor_list
#     coeff, factors = dmp_zz_factor(f, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/factortools.py", line 1142, in dmp_zz_factor
#     G, g = dmp_primitive(g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1818, in dmp_primitive
#     cont, v = dmp_content(f, u, K), u - 1
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1793, in dmp_content
#     cont = dmp_gcd(cont, c, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1625, in dmp_gcd
#     return dmp_inner_gcd(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1584, in dmp_inner_gcd
#     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1553, in _dmp_inner_gcd
#     return dmp_zz_heu_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1311, in dmp_zz_heu_gcd
#     result = _dmp_rr_trivial_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 911, in _dmp_rr_trivial_gcd
#     return _dmp_simplify_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 951, in _dmp_simplify_gcd
#     G = dmp_content(g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1793, in dmp_content
#     cont = dmp_gcd(cont, c, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1625, in dmp_gcd
#     return dmp_inner_gcd(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1584, in dmp_inner_gcd
#     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1553, in _dmp_inner_gcd
#     return dmp_zz_heu_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1311, in dmp_zz_heu_gcd
#     result = _dmp_rr_trivial_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 911, in _dmp_rr_trivial_gcd
#     return _dmp_simplify_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 951, in _dmp_simplify_gcd
#     G = dmp_content(g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1793, in dmp_content
#     cont = dmp_gcd(cont, c, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1625, in dmp_gcd
#     return dmp_inner_gcd(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1584, in dmp_inner_gcd
#     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1553, in _dmp_inner_gcd
#     return dmp_zz_heu_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1311, in dmp_zz_heu_gcd
#     result = _dmp_rr_trivial_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 911, in _dmp_rr_trivial_gcd
#     return _dmp_simplify_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 951, in _dmp_simplify_gcd
#     G = dmp_content(g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1793, in dmp_content
#     cont = dmp_gcd(cont, c, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1625, in dmp_gcd
#     return dmp_inner_gcd(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1584, in dmp_inner_gcd
#     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1553, in _dmp_inner_gcd
#     return dmp_zz_heu_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1311, in dmp_zz_heu_gcd
#     result = _dmp_rr_trivial_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 911, in _dmp_rr_trivial_gcd
#     return _dmp_simplify_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 951, in _dmp_simplify_gcd
#     G = dmp_content(g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1793, in dmp_content
#     cont = dmp_gcd(cont, c, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1625, in dmp_gcd
#     return dmp_inner_gcd(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1584, in dmp_inner_gcd
#     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1553, in _dmp_inner_gcd
#     return dmp_zz_heu_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1311, in dmp_zz_heu_gcd
#     result = _dmp_rr_trivial_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 911, in _dmp_rr_trivial_gcd
#     return _dmp_simplify_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 951, in _dmp_simplify_gcd
#     G = dmp_content(g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1793, in dmp_content
#     cont = dmp_gcd(cont, c, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1625, in dmp_gcd
#     return dmp_inner_gcd(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1584, in dmp_inner_gcd
#     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1553, in _dmp_inner_gcd
#     return dmp_zz_heu_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1311, in dmp_zz_heu_gcd
#     result = _dmp_rr_trivial_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 911, in _dmp_rr_trivial_gcd
#     return _dmp_simplify_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 951, in _dmp_simplify_gcd
#     G = dmp_content(g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1793, in dmp_content
#     cont = dmp_gcd(cont, c, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1625, in dmp_gcd
#     return dmp_inner_gcd(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1584, in dmp_inner_gcd
#     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1553, in _dmp_inner_gcd
#     return dmp_zz_heu_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1311, in dmp_zz_heu_gcd
#     result = _dmp_rr_trivial_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 911, in _dmp_rr_trivial_gcd
#     return _dmp_simplify_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 951, in _dmp_simplify_gcd
#     G = dmp_content(g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1793, in dmp_content
#     cont = dmp_gcd(cont, c, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1625, in dmp_gcd
#     return dmp_inner_gcd(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1584, in dmp_inner_gcd
#     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1553, in _dmp_inner_gcd
#     return dmp_zz_heu_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1311, in dmp_zz_heu_gcd
#     result = _dmp_rr_trivial_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 911, in _dmp_rr_trivial_gcd
#     return _dmp_simplify_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 951, in _dmp_simplify_gcd
#     G = dmp_content(g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1793, in dmp_content
#     cont = dmp_gcd(cont, c, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1625, in dmp_gcd
#     return dmp_inner_gcd(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1584, in dmp_inner_gcd
#     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1553, in _dmp_inner_gcd
#     return dmp_zz_heu_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1311, in dmp_zz_heu_gcd
#     result = _dmp_rr_trivial_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 911, in _dmp_rr_trivial_gcd
#     return _dmp_simplify_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 951, in _dmp_simplify_gcd
#     G = dmp_content(g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1793, in dmp_content
#     cont = dmp_gcd(cont, c, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1625, in dmp_gcd
#     return dmp_inner_gcd(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1584, in dmp_inner_gcd
#     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1553, in _dmp_inner_gcd
#     return dmp_zz_heu_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 1311, in dmp_zz_heu_gcd
#     result = _dmp_rr_trivial_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 911, in _dmp_rr_trivial_gcd
#     return _dmp_simplify_gcd(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 960, in _dmp_simplify_gcd
#     cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py", line 960, in <listcomp>
#     cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 1671, in dmp_quo
#     return dmp_div(f, g, u, K)[0]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 1629, in dmp_div
#     return dmp_rr_div(f, g, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 1389, in dmp_rr_div
#     c, R = dmp_rr_div(lc_r, lc_g, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 1389, in dmp_rr_div
#     c, R = dmp_rr_div(lc_r, lc_g, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 1389, in dmp_rr_div
#     c, R = dmp_rr_div(lc_r, lc_g, v, K)
#   [Previous line repeated 20 more times]
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 1397, in dmp_rr_div
#     h = dmp_mul_term(g, c, j, u, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 184, in dmp_mul_term
#     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 184, in <listcomp>
#     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 828, in dmp_mul
#     coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 828, in dmp_mul
#     coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py", line 832, in dmp_mul
#     return dmp_strip(h, u)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/inspect.py", line 1503, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/ultratb.py", line 182, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/tokenize.py", line 394, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/tokenize.py", line 363, in detect_encoding
#     first = read_or_stop()
#   File "/home/zubair/miniconda3/envs/test-ipopt/lib/python3.9/tokenize.py", line 321, in read_or_stop
#     return readline()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-10-15cc511119e7> in <module>
#       9
# ---> 10 M = sym.simplify(M)
#      11
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     591     if _eval_simplify is not None:
# --> 592         return _eval_simplify(**kwargs)
#     593
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py in _eval_simplify(self, **kwargs)
#    2484         # override simplify and have it return None
# -> 2485         return MatrixOperations.simplify(self, **kwargs)
#    2486
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py in simplify(self, **kwargs)
#    2374         """
# -> 2375         return self.applyfunc(lambda x: x.simplify(**kwargs))
#    2376
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py in applyfunc(self, f)
#    2025
# -> 2026         return self._eval_applyfunc(f)
#    2027
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py in _eval_applyfunc(self, f)
#    1965     def _eval_applyfunc(self, f):
# -> 1966         out = self._new(self.rows, self.cols, [f(x) for x in self])
#    1967         return out
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py in <listcomp>(.0)
#    1965     def _eval_applyfunc(self, f):
# -> 1966         out = self._new(self.rows, self.cols, [f(x) for x in self])
#    1967         return out
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/matrices/common.py in <lambda>(x)
#    2374         """
# -> 2375         return self.applyfunc(lambda x: x.simplify(**kwargs))
#    2376
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/core/basic.py in simplify(self, **kwargs)
#    1674         from sympy.simplify import simplify
# -> 1675         return simplify(self, **kwargs)
#    1676
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     695     if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 696         expr = trigsimp(expr, deep=True)
#     697
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py in trigsimp(expr, **opts)
#     509
# --> 510     return trigsimpfunc(expr)
#     511
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#     502         'fu': (lambda x: fu(x, **opts)),
# --> 503         'matching': (lambda x: futrig(x)),
#     504         'groebner': (lambda x: groebnersimp(x, **opts)),
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py in futrig(e, hyper, **kwargs)
#    1101     old = e
# -> 1102     e = bottom_up(e, _futrig)
#    1103
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1197                 rv = rv.func(*args)
# -> 1198             rv = F(rv)
#    1199         elif atoms:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py in _futrig(e)
#    1169         )]
# -> 1170     e = greedy(tree, objective=Lops)(e)
#    1171
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/strategies/core.py in minrule(expr)
#     110     def minrule(expr):
# --> 111         return min([rule(expr) for rule in rules], key=objective)
#     112     return minrule
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/strategies/core.py in <listcomp>(.0)
#     110     def minrule(expr):
# --> 111         return min([rule(expr) for rule in rules], key=objective)
#     112     return minrule
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/strategies/core.py in chain_rl(expr)
#      40         for rule in rules:
# ---> 41             expr = rule(expr)
#      42         return expr
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#    1146         TR11, _TR11, TR6, # reduce double angles and rewrite cos pows
# -> 1147         lambda x: _eapply(factor, x, trigs),
#    1148         TR14,  # factored powers of identities
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/simplify/trigsimp.py in _eapply(func, e, cond)
#    1194     if _is_Expr(e) or not e.args:
# -> 1195         return func(e)
#    1196     return e.func(*[
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polytools.py in factor(f, deep, *gens, **args)
#    6389     try:
# -> 6390         return _generic_factor(f, gens, args, method='factor')
#    6391     except PolynomialError as msg:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polytools.py in _generic_factor(expr, gens, args, method)
#    6061     opt['fraction'] = fraction
# -> 6062     return _symbolic_factor(sympify(expr), opt, method)
#    6063
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polytools.py in _symbolic_factor(expr, opt, method)
#    6001             return expr._eval_factor()
# -> 6002         coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    6003         return _keep_coeff(coeff, _factors_product(factors))
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polytools.py in _symbolic_factor_list(expr, opt, method)
#    5966
# -> 5967             _coeff, _factors = func()
#    5968             if _coeff is not S.One:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polytools.py in factor_list(f)
#    3335             try:
# -> 3336                 coeff, factors = f.rep.factor_list()
#    3337             except DomainError:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/polyclasses.py in factor_list(f)
#     794         """Returns a list of irreducible factors of ``f``. """
# --> 795         coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#     796         return coeff, [ (f.per(g), k) for g, k in factors ]
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/factortools.py in dmp_factor_list(f, u, K0)
#    1410             levels, f, v = dmp_exclude(f, u, K)
# -> 1411             coeff, factors = dmp_zz_factor(f, v, K)
#    1412
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/factortools.py in dmp_zz_factor(f, u, K)
#    1141
# -> 1142     G, g = dmp_primitive(g, u, K)
#    1143
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_primitive(f, u, K)
#    1817     """
# -> 1818     cont, v = dmp_content(f, u, K), u - 1
#    1819
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     959     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
# --> 960     cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#     961
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/euclidtools.py in <listcomp>(.0)
#     959     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
# --> 960     cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#     961
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_quo(f, g, u, K)
#    1670     """
# -> 1671     return dmp_div(f, g, u, K)[0]
#    1672
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_div(f, g, u, K)
#    1628     else:
# -> 1629         return dmp_rr_div(f, g, u, K)
#    1630
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1388         lc_r = dmp_LC(r, K)
# -> 1389         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1390
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1396         q = dmp_add_term(q, c, j, u, K)
# -> 1397         h = dmp_mul_term(g, c, j, u, K)
#    1398         r = dmp_sub(r, h, u, K)
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_mul_term(f, c, i, u, K)
#     183     else:
# --> 184         return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#     185
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in <listcomp>(.0)
#     183     else:
# --> 184         return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#     185
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_mul(f, g, u, K)
#     827         for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828             coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     829
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_mul(f, g, u, K)
#     827         for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828             coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     829
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/sympy/polys/densearith.py in dmp_mul(f, g, u, K)
#     831
# --> 832     return dmp_strip(h, u)
#     833
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/miniconda3/envs/test-ipopt/lib/python3.9/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
# Manipulator Equation 
EOM = M*ddq + G + C - Tau - Q 

# save the EOM in a file (saving the EOM saves lots of time)
import dill
dill.dump_session('unsimplified_biped_FW.db')

# %%
EOMs = sym.zeros(len(q),1)
for j in range(len(q)):
    EOMs[j] = EOM[j].simplify()

# %%
# save the EOM in a file (saving the EOM saves lots of time)
import dill
dill.dump_session('simplified_biped_FW.db')
