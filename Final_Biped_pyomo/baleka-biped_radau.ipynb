# %% [markdown]
# ## Closed Kinemtaic Chain hopper

# %%
# EOMs
# %reset
#import libraries
import sympy as sym
import numpy as np
import pickle as pickle

sym.init_printing()
from IPython.display import display #for pretty printing

# Symbols --------------------------------------------------
legs = ['A','B']
links = ['b','l1RA','l1LA','l2RA','l2LA','l1RB','l1LB','l2RB','l2LB']

#Parameters
m = {}
L = {}
I = {}
d = {}
g = sym.symbols('g')

for l in links:
    m.update({l: sym.symbols('m_{%s}'%l)})
    L.update({l: sym.symbols('L_{%s}'%l)})
    I.update({l: sym.symbols('I_{%s}'%l)})
    d.update({l: sym.symbols('d_{%s}'%l)})

#gen coordinates
x,y,thb = sym.symbols(['x','y','\\theta_{b}'])
dx,dy,dthb = sym.symbols(['\\dot{x}','\\dot{y}','\\dot{\\theta}_{b}'])
ddx,ddy,ddthb = sym.symbols(['\\ddot{x}','\\ddot{y}','\\ddot{\\theta}_{b}'])

th = {}
dth = {}
ddth = {}

for l in links[1:]:
    th.update({l: sym.symbols('\\theta_{%s}'%l)})
    dth.update({l: sym.symbols('\\dot{\\theta}_{%s}'%l)})
    ddth.update({l: sym.symbols('\\ddot{\\theta}_{%s}'%l)})

q = sym.Matrix([x]+[y]+[thb]+[th[l] for l in links[1:]])
dq = sym.Matrix([dx]+[dy]+[dthb]+[dth[l] for l in links[1:]])
ddq = sym.Matrix([ddx]+[ddy]+[ddthb]+[ddth[l] for l in links[1:]])

# positions
def get_R(th_in):    
    Rz = sym.Matrix([[sym.cos(th_in),-sym.sin(th_in),0],
                    [sym.sin(th_in),sym.cos(th_in),0],
                    [0,0,1]])
    
    R = Rz
    return R

pt = {'b': sym.Matrix([[x],[y],[0]])}
po = {'b': sym.Matrix([[0],[0],[thb]])}

for l in links[1:]:
    po.update({l: sym.Matrix([[0],[0],[th[l]]])})

sides = ['R','L']

kneep = {}
shoulder = {}
footp = {}
footv = {}
foota = {}

for leg in legs:
    for s in sides:
        if s == 'R':
            l = 0.06
        else:
            l=-0.06
        Rb = get_R(thb)
        R1 = get_R(th['l1%s%s'%(s,leg)])
        shoulder.update({(s,leg): pt['b'] + Rb*sym.Matrix([[l],[0],[0]]) })
        pt.update({'l1%s%s'%(s,leg):  shoulder[s,leg] + R1*sym.Matrix([[0],[-0.5*L['l1%s%s'%(s,leg)]],[0]])})
        kneep.update({(s,leg): shoulder[s,leg] + R1*sym.Matrix([[0],[-L['l1%s%s'%(s,leg)]],[0]])})

        R2 = get_R(th['l2%s%s'%(s,leg)])
        pt.update({'l2%s%s'%(s,leg): kneep[s,leg] + R2*sym.Matrix([[0],[-d['l2%s%s'%(s,leg)]*L['l2%s%s'%(s,leg)]],[0]])})

        footp.update({(s,leg): kneep[s,leg] + R2*sym.Matrix([[0],[-L['l2%s%s'%(s,leg)]],[0]])})
        footv.update({(s,leg): footp[s,leg].jacobian(q)*dq})
        foota.update({(s,leg): footv[s,leg].jacobian(q)*dq + footp[s,leg].jacobian(q)*ddq})
    
p = {}
v = {}
J = {}
for l in links:
    p.update({l: sym.Matrix([pt[l],po[l]])})
    v.update({l: p[l].jacobian(q)*dq})
    J.update({l: v[l].jacobian(dq)})
    
# ENERGY ---------------------------------------------------------------------------------------
T = sum([0.5*m[l]*(v[l][0]**2 + v[l][1]**2) for l in links]) + sum([0.5*I[l]*v[l][5]**2 for l in links])
V = sum([m[l]*g*p[l][1] for l in links])

# term 1
Lg1 = sym.zeros(len(q),1)
for i in range(len(q)):
    dT_ddq = sym.Matrix([sym.diff(T,dq[i])]) # get partial of T in dq_i
    Lg1[i] = dT_ddq.jacobian(q)*dq + dT_ddq.jacobian(dq)*ddq #...then get time derivative of that partial

# term 3
Lg3 = sym.Matrix([T]).jacobian(q).transpose() # partial of T in q

# term 4
Lg4 = sym.Matrix([V]).jacobian(q).transpose() # partial of U in q

#GEN FORCES-----------

Fcx = {}
Fcy = {}
for leg in legs:
    for s in sides:
        Fcx.update({(s,leg): sym.symbols('F_{cx%s%s}'%(s,leg))})
        Fcy.update({(s,leg): sym.symbols('F_{cy%s%s}'%(s,leg))})
        
# constraint forces
dj = sym.symbols('d_j')

Qc = {}
jointp = {}
for leg in legs:
    for s in sides:
        Fc = sym.Matrix([[Fcx[s,leg]],[Fcy[s,leg]],[0]])
        Fcr = footp[s,leg]
        Qc.update({(s,leg): Fcr.jacobian(q).transpose()*Fc})
        jointp.update({(s,leg): Fcr})
        
jointv = {}
jointa = {}
for leg in legs:
    for s in sides:
        jointv.update({(s,leg): jointp[s,leg].jacobian(q)*dq})
        jointa.update({(s,leg): jointv[s,leg].jacobian(q)*dq + jointv[s,leg].jacobian(dq)*ddq})

# ground reaction force
Gx = {}
Gy = {}
for leg in legs:
    for s in sides:
        Gx.update({leg: sym.symbols('G_{x%s}'%(leg))})
        Gy.update({leg: sym.symbols('G_{y%s}'%(leg))})

G_Q = {}
for leg in legs:
    G = sym.Matrix([[Gx[leg]],[Gy[leg]],[0]])
    G_r = footp['R',leg]
    G_Q.update({leg: G_r.jacobian(q).transpose()*G})
    
# actuators
tau = {}
for leg in legs:
    for s in sides:
        tau.update({(s,leg): sym.symbols('\\tau_{%s%s}'%(s,leg))})

tau_Q = sym.Matrix([[0],[0],[-(tau['R','A']+tau['L','A']+tau['R','B']+tau['L','B'])],[tau['R','A']],[tau['L','A']],[0],[0],[tau['R','B']],[tau['L','B']],[0],[0]])

Q = Qc['R','A'] + Qc['L','A'] + Qc['R','B'] + Qc['L','B'] + G_Q['A'] + G_Q['B'] + tau_Q 

# AND combine!
EOM = Lg1 - Lg3 + Lg4 - Q
#display(EOM)

# %%
# LAMBDIFY
from pyomo.environ import*
from pyomo.opt import SolverFactory
from pyomo.opt import SolverStatus, TerminationCondition

func_map = {'sin':sin, 'cos':cos} 

sym_list = [g] + [m[l] for l in links] +\
           [L[l] for l in links] +\
           [I[l] for l in links] +\
           [d[l] for l in links] + [dj] +\
           [x]+[y]+[thb] + [th[l] for l in links[1:]] +\
           [dx]+[dy]+[dthb] + [dth[l] for l in links[1:]] +\
           [ddx]+[ddy]+[ddthb]+ [ddth[l] for l in links[1:]] +\
           [tau[s,leg] for s in sides for leg in legs]+\
           [Gx[leg] for leg in legs] + [Gy[leg] for leg in legs]+\
           [Fcx[s,leg] for s in sides for leg in legs]+[Fcy[s,leg] for s in sides for leg in legs]

lamb_EOM = {}

DOFs = ['x'] + ['y'] +['th_b']+ ['th_%s'%l for l in links[1:]]

for dof_i,dof in enumerate(DOFs):
    lamb_EOM.update({dof: sym.lambdify(sym_list,EOM[dof_i],modules = [func_map])})

TDOFs = ['x','y']
lamb_footp = {}
lamb_footv = {}
for leg in legs:
    for dof_i,dof in enumerate(TDOFs):
        lamb_footp.update({(leg,dof): sym.lambdify(sym_list,footp['R',leg][dof_i],modules = [func_map])})
        lamb_footv.update({(leg,dof): sym.lambdify(sym_list,footv['R',leg][dof_i],modules = [func_map])})

lamb_jointp = {}
lamb_jointv = {}
lamb_jointa = {}
for leg in legs:
    for s in sides:
        for dof_i,dof in enumerate(TDOFs):
            lamb_jointp.update({(s,leg,dof): sym.lambdify(sym_list,jointp[s,leg][dof_i],modules = [func_map])})
            lamb_jointv.update({(s,leg,dof): sym.lambdify(sym_list,jointv[s,leg][dof_i],modules = [func_map])})
            lamb_jointa.update({(s,leg,dof): sym.lambdify(sym_list,jointa[s,leg][dof_i],modules = [func_map])})

# %%
# PARAMETERS:
mass = {'b': 13.77,
       'l1RA': 0.07330,
       'l1LA': 0.07330,
       'l2RA': 0.360,
       'l2LA': 0.252,
       'l1RB': 0.07330,
       'l1LB': 0.07330,
       'l2RB': 0.360,
       'l2LB': 0.252}

length = {'b': 0.250,
         'l1RA': 0.1745,
         'l1LA': 0.1745,
         'l2RA': 0.360,
         'l2LA': 0.300,
         'l1RB': 0.1745,
         'l1LB': 0.1745,
         'l2RB': 0.360,
         'l2LB': 0.300}

inertia = {'b': 1962140095.78/(1000*1000**2),
          'l1RA': 5419395.39/(1000*1000**2),
          'l1LA': 5419395.39/(1000*1000**2),
          'l2RA': 11800738.55/(1000*1000**2),
          'l2LA': 9382285.15/(1000*1000**2),
          'l1RB': 5419395.39/(1000*1000**2),
          'l1LB': 5419395.39/(1000*1000**2),
          'l2RB': 11800738.55/(1000*1000**2),
          'l2LB': 9382285.15/(1000*1000**2)}

# %%
P = 2
def get_var_list(m,n,p):
    var_list = [m.g]+\
                [m.m[l] for l in links]+\
                [m.l[l] for l in links]+\
                [m.I[l] for l in links]+\
                [m.dCOM[l] for l in links]+[m.dj]+\
                [m.q[n,p,dof] for dof in DOFs]+\
                [m.dq[n,p,dof] for dof in DOFs]+\
                [m.ddq[n,p,dof] for dof in DOFs]+\
                [m.tau[n,s,l] for s in sides for l in legs]+\
                [m.GRF[n,p,l,dof] for dof in TDOFs for l in legs]+\
                [m.Fc[n,p,s,l,dof] for dof in TDOFs for s in sides for l in legs]
    return var_list

def create_model(N,hm,mu):
    m = ConcreteModel()
    
    #SETS-------------------------
    m.N =RangeSet(N)
    m.leg = Set(initialize = legs)
    m.L =Set(initialize = links)
    m.DOF = Set(initialize= DOFs)
    m.TDOF = Set(initialize = TDOFs)
    m.S=Set(initialize = sides)
    
    #Params--------------------------
    m.g = Param(initialize = 9.81)
    m.m = Param(m.L, initialize = mass)
    m.l = Param(m.L, initialize = length)
    m.I = Param(m.L, initialize = inertia)
    m.dCOM = Param(m.L, initialize = 0.5)
    m.dj = Param(initialize = length['l2LA'])
    signs = ['ps','ng']
    m.sgn = Set(initialize = signs)
    m.P = Set(initialize = range(P+1))
    #VARIABLES----------------------
    #gen coordinates
    m.q = Var(m.N,m.P,m.DOF)
    m.dq = Var(m.N,m.P,m.DOF)
    m.ddq = Var(m.N,m.P,m.DOF)
    
    for n in range(1,N+1):
        for p in range(P+1):
            for leg in legs:
                m.q[n,p,'x'].setlb(0.0)
                m.q[n,p,'y'].setlb(0.3)
                m.q[n,p,'th_b'].setlb(0)
                m.q[n,p,'th_b'].setub(np.pi/2)
                m.q[n,p,'th_l1R%s'%leg].setlb(np.pi/18)
                m.q[n,p,'th_l1R%s'%leg].setub(5*np.pi/6)
                m.q[n,p,'th_l1L%s'%leg].setlb(-5*np.pi/6)
                m.q[n,p,'th_l1L%s'%leg].setub(-np.pi/18)
    
    #forces
    m.tau = Var(m.N,m.S,m.leg)
    m.Fc = Var(m.N,m.P,m.S,m.leg,m.TDOF)
    m.GRF = Var(m.N,m.P,m.leg,m.TDOF)
    
    for n in range(1,N+1):
        for p in range(P+1):
            for leg in legs:
                m.GRF[n,p,leg,'y'].setlb(0)
    #TIME AND INTEGRATION ---------------------------------------------------------------------------------------------------

    # timestep
    m.hm = Param(initialize = hm, mutable = True) # master timestep
    m.h = Var(m.N, bounds = (0.8,1.2))
    
    # Integration constraints 
    radau_mat = [[0.416666666666667, -0.0833333333333333],
                 [0.75, 0.25]]

    def integrate_p(m,n,p,dof):
        if p == 0:
            if n == 1: return Constraint.Skip
            else:
                return m.q[n,0,dof] == m.q[n-1,P,dof]
        else:
            vel = sum([radau_mat[p-1][pp-1]*m.dq[n,pp,dof] for pp in range(1,P+1)])
            return m.q[n,p,dof] == m.q[n,0,dof] + m.h[n]*m.hm*vel
    m.integrate_p = Constraint(m.N, m.P, m.DOF, rule = integrate_p)

    def integrate_v(m,n,p,dof):
        if p == 0:
            if n == 1: return Constraint.Skip
            else:
                return m.dq[n,0,dof] == m.dq[n-1,P,dof]
        else:
            acc = sum([radau_mat[p-1][pp-1]*m.ddq[n,pp,dof] for pp in range(1,P+1)])
            return m.dq[n,p,dof] == m.dq[n,0,dof] + m.h[n]*m.hm*acc
    m.integrate_v = Constraint(m.N, m.P, m.DOF, rule = integrate_v)
    
    def dynamics(m,n,p,dof):
        var_list = get_var_list(m,n,p)
        return lamb_EOM[dof](*var_list) == 0
    m.dynamic = Constraint(m.N,m.P,m.DOF, rule = dynamics)
    
    # motor model --------------------------------------------------------------------------------------
    max_rpm = 445/9
    max_dth = max_rpm*2*np.pi/60
    max_tau = 38*9
    
    for n in range(1,N+1):
        for s in sides:
            for leg in legs:
                m.tau[n,s,leg].setlb(-max_tau)
                m.tau[n,s,leg].setub(max_tau)
            # m.dq[n,'th_l1%s'%s].setlb(-max_dth/2)
            # m.dq[n,'th_l1%s'%s].setub(max_dth/2)
    
    def speed_bounds(omega):
            ub =(-(max_tau)/(max_dth))*omega + max_tau
            lb = (-(max_tau)/(max_dth))*omega - max_tau
            return(lb,ub)
            
    def motor_torque_speed_curve(m,n,p,s,leg,sgn):
        lb,ub = speed_bounds(m.dq[n,p,'th_l1R%s'%leg])
        if sgn == 'ps':
            return m.tau[n,s,leg] <= ub
        else:
            return m.tau[n,s,leg] >= lb
        return Constraint.Skip
    m.motor_torque_speed_curve = Constraint(m.N, m.P ,m.S, m.leg, m.sgn, rule = motor_torque_speed_curve)
    
    # connection -------------------------------------------------------------------------------------
    m.jointp = Var(m.N,m.P ,m.S, m.leg, m.TDOF)
    def get_jointp(m,n,p,s,leg,dof):
        var_list = get_var_list(m,n,p)
        return m.jointp[n,p,s,leg,dof] == lamb_jointp[s,leg,dof](*var_list)
    m.get_jointp = Constraint(m.N, m.P,m.S, m.leg, m.TDOF, rule = get_jointp)
    
    def constraint_forces(m,n,p,leg,dof):
        return m.Fc[n,p,'L',leg,dof] == -m.Fc[n,p,'R',leg,dof]
    m.constraint_forces = Constraint(m.N,m.P,m.leg,m.TDOF, rule = constraint_forces)
    
    def connect_p(m,n,p,leg,dof):
        return m.jointp[n,p,'R',leg,dof] == m.jointp[n,p,'L',leg,dof]
    m.connect_p = Constraint(m.N,m.P,m.leg,m.TDOF, rule = connect_p)
    
    #GROUND -------------------------------------------------
    
    
    m.footp = Var(m.N,m.P,m.leg,m.TDOF, bounds = (0.0,None))
    def def_footp(m,n,p,leg,dof):
        if dof == 'x':
            return Constraint.Skip
        else:
            var_list = get_var_list(m,n,p)
            return m.footp[n,p,leg,dof] == lamb_footp[leg,dof](*var_list)
    m.def_footp = Constraint(m.N,m.P, m.leg, m.TDOF, rule = def_footp)
        
    m.footv = Var(m.N,m.P, m.leg, m.TDOF)
    def def_footv(m,n,p,leg,dof):
        if dof == 'y': return Constraint.Skip
        else:
             var_list = get_var_list(m,n,p)
        return m.footv[n,p,leg,dof] == lamb_footv[leg,dof](*var_list)
    m.def_footv = Constraint(m.N,m.P, m.leg, m.TDOF, rule = def_footv)
    
    m.contact_penalty = Var(m.N,m.P, m.leg, bounds = (0.0,None))
    def contact_complementarity(m,n,p,leg):
        if n<N:
            return m.footp[n+1,p,leg,'y']*m.GRF[n,p,leg,'y']<=m.contact_penalty[n,p,leg] 
        else:
            return m.footp[n,p,leg,'y']*m.GRF[n,p,leg,'y']<=m.contact_penalty[n,p,leg] 
    m.contact_complementarity = Constraint(m.N,m.P, m.leg, rule = contact_complementarity)
    
    #friction
    m.mu = Param(initialize = mu)
    
    GDOFs = ['x']
    m.GDOF = Set(initialize = GDOFs)
    d_res = 2
    directions = RangeSet(d_res)
    m.D = Set(initialize = directions) #directions
    def get_d(m,dof,d):
        th = np.linspace(0,2*np.pi,d_res+1)
        if dof == 'x':
            return np.cos(th[d-1])
        if dof == 'z':
            return np.sin(th[d-1])
    m.d = Param(m.GDOF, m.D, initialize = get_d) # unit vectors
    
    m.alpha = Var(m.N,m.P, m.leg, m.D, bounds = (0,1))
    m.F = Var(m.N,m.P, m.leg, bounds = (0,None)) #friction force
    m.gamma = Var(m.N,m.P, m.leg, bounds = (0,None))
    m.dir = Var(m.N,m.P, m.leg, m.D, bounds = (0,None))
    
    def def_gamma(m,n,p,leg,d):
        dx = m.footv[n,p,leg,'x']
        return m.gamma[n,p,leg] + sum([m.d[dof,d]*dx for dof in GDOFs]) == m.dir[n,p,leg,d]
    m.def_gamma = Constraint(m.N,m.P,m.leg,m.D, rule = def_gamma)
    
    def friction(m,n,p,leg): # insert velocity-dependent friction law here
        dx = m.footv[n,p,leg,'x']
        fm = m.mu
        return m.F[n,p,leg] == fm*m.GRF[n,p,leg,'y']
    m.friction = Constraint(m.N,m.P, m.leg, rule = friction)

    def get_GRF(m,n,p,leg,dof):
        return m.GRF[n,p,leg,dof] == m.F[n,p,leg]*sum([m.alpha[n,p,leg,d]*m.d[dof,d] for d in directions])
    m.get_GRF = Constraint(m.N,m.P, m.leg, m.GDOF, rule = get_GRF)

    # complementarity
    m.direction_penalty = Var(m.N,m.P, m.leg, m.D, bounds = (0.0,None))
    m.magnitude_penalty = Var(m.N,m.P, m.leg, bounds = (0,None))

    def direction_complementarity(m,n,p,leg,d):
        A = m.alpha[n,p,leg,d]
        B = m.dir[n,p,leg,d]
        return  A*B <= m.direction_penalty[n,p,leg,d]
    m.direction_complementarity = Constraint(m.N,m.P, m.leg, m.D, rule = direction_complementarity)

    def magnitude_complementarity(m,n,p,leg):
        A = m.gamma[n,p,leg]
        B = 1-sum([m.alpha[n,p,leg,d] for d in directions])
        return A*B <= m.magnitude_penalty[n,p,leg]
    m.magnitude_complementarity = Constraint(m.N,m.P, m.leg, rule = magnitude_complementarity)
    
    m.y_des = Param(initialize = 0)
    
    m.virtual_constraint_penalty = Var(m.N, bounds = (0.0,None))
    def virtual_constraint(m,n,p):
        if n == 1: return Constraint.Skip
        return (m.q[n,:,'th_b'] - m.y_des)**2 <= m.virtual_constraint_penalty[n] 
    m.virtual_constraint = Constraint(m.N,m.P, rule = virtual_constraint)
    
    def MinPenalty(m):
        return sum([m.contact_penalty[n,:,leg] + m.magnitude_penalty[n,:,leg] for n in range(1,N+1)  for leg in legs]) +\
                sum([m.direction_penalty[n,:,leg,d] for n in range(1,N+1) for d in range(1,d_res+1) for leg in legs])+\
                sum([m.virtual_constraint_penalty[n] for n in tange(1,N+1)])
                #sum([m.tau[n,s,leg]**2 for n in range(1,N+1) for s in sides for leg in legs])
    m.MinPenalty = Objective(rule = MinPenalty)

   
    #m.MinPenalty.deactivate()
    
    # def CostFun(m):
    #     pen_sum = sum(m.contact_penalty[:]) + sum(m.magnitude_penalty[:]) + sum(m.direction_penalty[:,:])
    #     torque_sum = 0
    #     for n in range(1,N+1):
    #         for s in sides:
    #             torque_sum += m.tau[n,s]**2
    #     return pen_sum
    # m.Cost = Objective(rule = CostFun)
    # m.Cost.deactivate()
    
    def ss_p(m,dof):
        if dof != 'x': return Constraint.Skip
        return m.q[1,0,dof] == m.q[N,0,dof]
    m.ss_p = Constraint(m.DOF, rule = ss_p)
    
    def ss_v(m,dof):
        return m.dq[1,0,dof] == m.dq[N,0,dof]
    m.ss_v = Constraint(m.DOF, rule = ss_v)
    
    def MaxHeight(m):
        return -m.q[1,0,'y']
    m.MaxHeight = Objective(rule = MaxHeight)
    m.MaxHeight.deactivate()
    
    return m

# %%
def init_opt(): # initializes solver
    opt = SolverFactory('ipopt',executable = '/home/immanuel/Solver/build/bin/ipopt')
    opt.options["linear_solver"] = 'ma97'
    opt.options["print_level"] = 5 # prints a log with each iteration (you want to this - it's the only way to see progress.)
    opt.options["max_iter"] = 30000 # maximum number of iterations
    opt.options["max_cpu_time"] = 3600 # maximum cpu time in seconds
    opt.options["Tol"] = 1e-6 # the tolerance for feasibility. Considers constraints satisfied when they're within this margin.
    
    opt.options["OF_acceptable_obj_change_tol"] = 1e-4
    opt.options["OF_ma86_scaling"] = 'none'
    
    return opt

opt = init_opt()

# %%
N = 100+1
hm = 0.02
mu = 1.0
m = create_model(N,hm,mu)
# # HIGH DROP -----------------------------------------------------------------------------------------------------------------

# for leg in legs:
#     m.footp[1,0,leg,'y'].fix(0)
#     m.footp[1,0,leg,'x'].fix(0)
    
m.q[:,:,'x'].setub(3)
m.q[1,0,'x'].fix(0)

for n in range(1,int(0.5*(N-1))):
    m.footp[n,0,'A','y'].fix(0)
    m.footv[n,0,'A','x'].fix(0)
    m.GRF[n,0,'A','y'].setlb(0)
    m.GRF[n,0,'B','y'].fix(0)
    
for n in range(int(0.5*(N-1))+1,N+1):
    m.footv[n,0,'B','x'].fix(0)
    #m.footp[n,'A','y'].fix(0)
    m.footp[n,0,'B','y'].fix(0)
    m.GRF[n,0,'B','y'].setlb(0)
    m.GRF[n,0,'A','y'].fix(0)
    
#m.footp[0.5*(N-1),'B','y'].setlb(0.2)
# m.footp[0.5*(N-1),'A','y'].setub(0.01)
# for n in range(12,N+1):
#     m.footp[n,'B','y'].setub(0)
#     m.footv[n,'B','x'].setub(0.1)

# m.footp[(N),'A','y'].setlb(0.2)

# for n in range(12,N+1):
#     m.footp[n,'B','y'].fix(0)
#     m.footv[n,'B','x'].fix(0)
#     m.footp[n,'A','y'].setlb(0.2)

# for n in range(22,30+1):
#     m.footp[n,'A','y'].fix(0)
#     m.footv[n,'A','x'].fix(0)
#     m.footp[n,'B','y'].setlb(0.2)

# for n in range(32,N+1):
#     m.footp[n,'B','y'].fix(0)
#     m.footv[n,'B','x'].fix(0)
#     m.footp[n,'A','y'].setlb(0.2)

# for leg in legs:
#     m.footp[N,leg,'y'].fix(0)
#     m.footp[N,leg,'x'].fix(2)
# for leg in legs:
#     m.footp[N,leg,'y'].fix(0)
#     m.footp[N,leg,'x'].setlb(0.5)

m.q[(N),0,'x'].setlb(1)

# m.footp[N,'A','y'].fix(0.3)
# m.q[1,'y'].setlb(0.2)
# m.q[1,'x'].fix(0)
# m.q[:,'th_l1RA'].fix(np.pi/4)
#m.q[1,'x'].fix(0)
#m.q[1,'th_b'].fix(0)
#m.footp[1,'y'].fix(0)
#rest pose
#m.dq[1,:].fix(0)
m.h[1].fix(1)

#final
# m.q[0.5*(N-1),'x'].fix(2)
# m.footp[0.5*(N-1),'A','x'].fix(2)
#m.q[N,'y'].setlb(0.9)
#m.footp[N,'x'].setlb(0)
#m.footp[N,'y'].fix(0)
#m.q[N,'th_b'].fix(0)
#m.dq[N,:].fix(0)
#set initial pose


# m.footp[0.5*(N-1),'y'].setlb(0.2)
#m.q[0.5*(N-1),'y'].setlb(0.6)
#m.footp[0.5*(N-1),'x'].fix(0)
# m.q[0.5*]
# for n in range(1,N+1):
#     for leg in legs:
#         m.footp[n,leg,'x'].fix(0)
# m.footp[0.5*(N-1),'x'].setub(0.01)


opt = init_opt()

results = opt.solve(m,tee = True)
# Out:
# Ipopt 3.14.4: linear_solver=ma97
# print_level=5
# max_iter=30000
# max_cpu_time=3600
# Tol=1e-06
# option_file_name=/tmp/tmpzsd6wnb3_ipopt.opt
#
# Using option file "/tmp/tmpzsd6wnb3_ipopt.opt".
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.4, running with linear solver ma97.
#
# Number of nonzeros in equality constraint Jacobian...:   132952
# Number of nonzeros in inequality constraint Jacobian.:    12326
# Number of nonzeros in Lagrangian Hessian.............:    68136
#
# Total number of variables............................:    23534
#                      variables with only lower bounds:     6163
#                 variables with lower and upper bounds:     3533
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    18773
# Total number of inequality constraints...............:     4848
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:     4848
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4239976e+01 1.50e+02 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.7224303e+01 1.48e+02 1.01e+02  -1.0 8.82e+01  -4.0 2.33e-04 9.80e-03f  1
#    2  2.7231293e+01 1.48e+02 8.19e+01  -1.0 9.29e+01   1.8 1.10e-03 5.29e-05h  1
#    3  2.7244493e+01 1.48e+02 1.04e+02  -1.0 7.26e+01   1.4 3.75e-04 4.67e-05h  1
#    4r 2.7244493e+01 1.48e+02 9.99e+02   2.2 0.00e+00   0.9 0.00e+00 2.84e-07R  3
#    5r 1.0957005e+03 1.01e+02 9.96e+02   2.2 1.76e+04    -  2.72e-04 2.88e-03f  1
#    6  1.0954770e+03 1.00e+02 3.54e+02  -1.0 6.49e+00   0.4 7.47e-02 3.50e-03h  1
#    7  1.0955283e+03 1.00e+02 3.34e+03  -1.0 1.38e+02  -0.1 4.15e-03 3.53e-05h  1
#    8  1.0955698e+03 1.00e+02 7.07e+05  -1.0 1.99e+02  -0.5 4.05e-03 1.91e-05h  1
#    9  1.1079086e+03 1.00e+02 5.82e+05  -1.0 1.93e+02  -1.0 4.01e-03 4.70e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.2777102e+03 9.45e+01 7.64e+06  -1.0 1.75e+02  -1.5 8.78e-03 5.50e-02h  1
#   11  1.3339921e+03 9.27e+01 6.05e+06  -1.0 3.47e+02  -2.0 2.61e-02 1.83e-02h  1
#   12  1.3748653e+03 9.16e+01 3.23e+06  -1.0 1.71e+02  -1.5 6.26e-02 1.26e-02h  1
#   13  1.3838848e+03 9.13e+01 1.10e+07  -1.0 2.32e+02  -2.0 4.69e-02 2.60e-03h  1
#   14  1.5919092e+03 8.59e+01 1.02e+07  -1.0 1.64e+02  -1.6 5.92e-02 6.00e-02h  1
#   15  1.6122240e+03 8.52e+01 1.48e+07  -1.0 1.68e+02  -1.2 3.54e-02 7.32e-03h  1
#   16  1.7036861e+03 8.25e+01 2.46e+07  -1.0 1.89e+02  -1.6 9.53e-02 3.26e-02h  1
#   17  1.8809727e+03 7.64e+01 1.54e+07  -1.0 1.63e+02  -1.2 2.65e-02 7.46e-02h  1
#   18  1.8891572e+03 7.60e+01 2.54e+07  -1.0 1.56e+02  -0.8 6.76e-02 5.36e-03h  1
#   19  1.9894178e+03 7.10e+01 1.84e+07  -1.0 1.96e+02  -1.3 3.08e-02 6.57e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.9904105e+03 7.09e+01 1.83e+07  -1.0 1.18e+02   0.1 1.21e-03 1.54e-03h  1
#   21  1.9946558e+03 7.04e+01 1.72e+07  -1.0 4.48e+02  -0.4 9.92e-04 7.20e-03h  1
#   22  1.9949637e+03 7.03e+01 1.80e+07  -1.0 2.09e+02   0.0 5.80e-03 6.11e-04h  1
#   23  1.9951765e+03 7.03e+01 2.39e+07  -1.0 1.67e+02  -0.5 3.72e-02 2.83e-04h  1
#   24  2.0228044e+03 6.78e+01 4.02e+07  -1.0 2.11e+02  -1.0 1.47e-01 3.55e-02h  1
#   25  2.0456898e+03 6.48e+01 3.52e+07  -1.0 1.63e+02  -0.5 2.16e-02 4.47e-02h  1
#   26  2.0498980e+03 6.34e+01 4.25e+07  -1.0 2.52e+02  -1.0 7.82e-02 2.20e-02h  1
#   27  2.0537146e+03 6.14e+01 4.87e+07  -1.0 1.59e+02  -0.6 8.66e-02 3.09e-02h  1
#   28  2.0535755e+03 6.12e+01 5.44e+07  -1.0 2.94e+02  -1.1 4.74e-02 2.69e-03h  1
#   29  2.0539377e+03 6.11e+01 5.67e+07  -1.0 1.75e+02  -0.6 2.16e-02 1.89e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  2.0542828e+03 6.08e+01 5.67e+07  -1.0 3.92e+02  -1.1 7.04e-03 4.83e-03h  1
#   31  2.0545954e+03 6.07e+01 5.80e+07  -1.0 1.57e+02  -0.7 1.32e-02 1.79e-03h  1
#   32  2.0512677e+03 6.04e+01 5.74e+07  -1.0 1.73e+03  -1.2 1.80e-03 4.59e-03h  1
#   33  2.0565758e+03 5.83e+01 5.48e+07  -1.0 1.58e+02  -0.7 3.03e-02 3.48e-02h  1
#   34  2.0562375e+03 5.82e+01 5.76e+07  -1.0 7.81e+01   0.6 2.47e-02 1.63e-03h  1
#   35  2.0559273e+03 5.80e+01 5.71e+07  -1.0 1.06e+02   0.1 7.58e-04 3.59e-03h  1
#   36  2.0557325e+03 5.74e+01 5.65e+07  -1.0 1.36e+02  -0.4 1.07e-02 1.06e-02h  1
#   37  2.0539699e+03 5.65e+01 5.36e+07  -1.0 1.31e+03  -0.8 2.20e-06 1.62e-02h  1
#   38  2.0538278e+03 5.64e+01 5.49e+07  -1.0 9.03e+01   0.5 1.17e-02 5.83e-04h  1
#   39  2.0537960e+03 5.64e+01 5.99e+07  -1.0 1.06e+02   0.0 4.01e-02 2.11e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  2.0510206e+03 5.46e+01 5.40e+07  -1.0 1.33e+02  -0.5 5.80e-04 3.31e-02h  1
#   41  2.0501300e+03 5.41e+01 5.37e+07  -1.0 2.23e+02  -0.9 8.02e-03 7.53e-03h  1
#   42  2.0445036e+03 5.24e+01 5.17e+07  -1.0 1.33e+02  -0.5 3.14e-02 3.30e-02h  1
#   43  2.0442947e+03 5.23e+01 5.50e+07  -1.0 2.64e+02  -1.0 2.77e-02 8.48e-04h  1
#   44  2.0385498e+03 5.11e+01 5.58e+07  -1.0 1.34e+02  -0.6 4.04e-02 2.38e-02h  1
#   45  2.0358856e+03 5.07e+01 6.10e+07  -1.0 4.47e+02  -1.0 5.38e-02 7.76e-03h  1
#   46  2.0181982e+03 4.76e+01 5.45e+07  -1.0 1.34e+02  -0.6 3.58e-02 6.00e-02h  1
#   47  2.0101171e+03 4.68e+01 5.16e+07  -1.0 1.04e+02  -0.2 3.27e-03 1.84e-02h  1
#   48  2.0010056e+03 4.57e+01 5.17e+07  -1.0 1.49e+02  -0.7 3.17e-02 2.19e-02h  1
#   49  2.0005727e+03 4.57e+01 5.30e+07  -1.0 6.25e+01   0.7 1.10e-02 7.93e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.9942671e+03 4.51e+01 5.10e+07  -1.0 8.06e+01   0.2 2.21e-03 1.25e-02h  1
#   51  1.9868619e+03 4.44e+01 4.95e+07  -1.0 1.07e+02  -0.3 9.66e-03 1.51e-02h  1
#   52  1.9806432e+03 4.39e+01 4.73e+07  -1.0 8.50e+02  -0.8 3.53e-06 1.25e-02f  1
#   53  1.9802016e+03 4.39e+01 4.72e+07  -1.0 6.28e+01   0.6 2.51e-04 8.14e-04h  1
#   54  1.9800809e+03 4.38e+01 5.01e+07  -1.0 4.21e+01   1.0 2.19e-02 2.17e-04h  1
#   55  1.9702185e+03 4.30e+01 4.68e+07  -1.0 8.55e+01   0.5 1.26e-03 1.89e-02f  1
#   56  1.9612425e+03 4.23e+01 4.47e+07  -1.0 4.38e+01   0.9 7.05e-03 1.74e-02h  1
#   57  1.9606948e+03 4.22e+01 4.49e+07  -1.0 2.79e+01   1.4 3.23e-03 1.09e-03h  1
#   58  1.9560817e+03 4.18e+01 4.35e+07  -1.0 4.56e+01   0.9 1.97e-03 9.48e-03h  1
#   59  1.9560008e+03 4.18e+01 4.72e+07  -1.0 2.95e+01   1.3 2.77e-02 1.66e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  1.9447135e+03 4.07e+01 4.65e+07  -1.0 5.00e+01   0.8 2.99e-02 2.59e-02h  1
#   61  1.9410123e+03 4.04e+01 4.50e+07  -1.0 3.07e+01   1.3 5.56e-04 8.55e-03h  1
#   62  1.9375574e+03 4.01e+01 4.53e+07  -1.0 1.78e+01   1.7 1.19e-02 7.24e-03h  1
#   63  1.9367471e+03 4.00e+01 4.57e+07  -1.0 3.24e+01   1.2 5.60e-03 1.94e-03h  1
#   64  1.9363260e+03 4.00e+01 4.70e+07  -1.0 1.89e+01   1.6 1.03e-02 9.05e-04h  1
#   65  1.9248331e+03 3.89e+01 4.81e+07  -1.0 3.40e+01   1.2 4.67e-02 2.81e-02f  1
#   66  1.9239084e+03 3.88e+01 5.10e+07  -1.0 2.01e+01   1.6 2.51e-02 2.07e-03h  1
#   67  1.9225373e+03 3.86e+01 5.05e+07  -1.0 3.60e+01   1.1 7.83e-04 3.51e-03h  1
#   68  1.9185038e+03 3.83e+01 4.97e+07  -1.0 2.16e+01   1.5 6.84e-03 9.22e-03f  1
#   69  1.9148379e+03 3.80e+01 4.84e+07  -1.0 1.58e+01   2.0 7.95e-04 7.66e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  1.9143533e+03 3.79e+01 5.03e+07  -1.0 2.30e+01   1.5 1.57e-02 1.15e-03h  1
#   71  1.9130355e+03 3.78e+01 5.20e+07  -1.0 1.68e+01   1.9 1.76e-02 2.85e-03h  1
#   72  1.9128257e+03 3.78e+01 5.57e+07  -1.0 2.49e+01   1.4 2.97e-02 5.20e-04h  1
#   73  1.9042423e+03 3.69e+01 5.14e+07  -1.0 4.13e+01   1.0 3.21e-04 2.41e-02f  1
#   74  1.9034424e+03 3.68e+01 5.47e+07  -1.0 5.75e+01   0.5 2.92e-02 2.22e-03h  1
#   75  1.9026958e+03 3.68e+01 5.45e+07  -1.0 4.48e+02   0.0 4.96e-04 1.75e-03h  1
#   76  1.9014525e+03 3.66e+01 5.64e+07  -1.0 6.08e+01   0.4 2.06e-02 3.41e-03h  1
#   77  1.8989326e+03 3.64e+01 5.53e+07  -1.0 4.67e+01   0.9 7.92e-04 7.18e-03h  1
#   78  1.8980630e+03 3.63e+01 5.64e+07  -1.0 3.03e+01   1.3 1.30e-02 2.29e-03h  1
#   79  1.8944238e+03 3.60e+01 5.49e+07  -1.0 1.81e+01   1.7 2.30e-04 8.56e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  1.8938728e+03 3.59e+01 5.51e+07  -1.0 3.45e+01   1.2 3.64e-03 1.48e-03h  1
#   81  1.8916250e+03 3.57e+01 5.53e+07  -1.0 1.90e+01   1.7 9.00e-03 5.40e-03h  1
#   82  1.8879223e+03 3.54e+01 5.35e+07  -1.0 4.08e+01   1.2 3.48e-04 1.02e-02f  1
#   83  1.8876283e+03 3.53e+01 5.62e+07  -1.0 1.98e+01   1.6 2.28e-02 7.23e-04h  1
#   84  1.8818781e+03 3.49e+01 5.50e+07  -1.0 1.44e+01   2.0 8.63e-03 1.30e-02h  1
#   85  1.8796887e+03 3.47e+01 5.41e+07  -1.0 2.11e+01   1.6 1.41e-03 5.54e-03h  1
#   86  1.8770283e+03 3.45e+01 6.00e+07  -1.0 1.47e+01   2.0 5.62e-02 6.20e-03h  1
#   87  1.8744107e+03 3.42e+01 6.05e+07  -1.0 2.22e+01   1.5 1.43e-02 6.79e-03h  1
#   88  1.8671367e+03 3.35e+01 5.78e+07  -1.0 4.65e+01   1.0 9.54e-03 2.13e-02h  1
#   89  1.8663450e+03 3.34e+01 5.84e+07  -1.0 3.91e+01   1.5 7.59e-03 2.12e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  1.8608513e+03 3.30e+01 6.24e+07  -1.0 1.57e+01   1.9 5.34e-02 1.33e-02h  1
#   91  1.8571830e+03 3.27e+01 6.10e+07  -1.0 1.18e+01   2.3 1.18e-03 8.61e-03h  1
#   92  1.8547577e+03 3.25e+01 6.08e+07  -1.0 1.66e+01   1.8 7.59e-03 6.07e-03h  1
#   93  1.8511190e+03 3.22e+01 6.22e+07  -1.0 1.21e+01   2.3 2.46e-02 8.69e-03h  1
#   94  1.8503271e+03 3.22e+01 6.20e+07  -1.0 1.74e+01   1.8 1.94e-03 2.03e-03h  1
#   95  1.8475292e+03 3.19e+01 6.06e+07  -1.0 2.99e+01   1.3 2.48e-04 8.08e-03f  1
#   96  1.8471903e+03 3.19e+01 6.54e+07  -1.0 1.82e+01   1.7 4.24e-02 8.83e-04h  1
#   97  1.8385609e+03 3.11e+01 6.10e+07  -1.0 3.08e+01   1.2 3.74e-04 2.54e-02f  1
#   98  1.8380248e+03 3.10e+01 6.81e+07  -1.0 1.88e+01   1.7 6.27e-02 1.43e-03h  1
#   99  1.8272588e+03 3.00e+01 6.23e+07  -1.0 3.29e+01   1.2 3.74e-04 3.24e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  1.8258494e+03 2.99e+01 6.25e+07  -1.0 2.68e+01   1.6 7.32e-03 3.91e-03h  1
#  101  1.8249114e+03 2.98e+01 6.93e+07  -1.0 1.30e+01   2.0 6.24e-02 2.42e-03h  1
#  102  1.8206026e+03 2.95e+01 6.86e+07  -1.0 9.76e+00   2.5 1.14e-02 1.09e-02h  1
#  103  1.8205300e+03 2.95e+01 7.01e+07  -1.0 1.37e+01   2.0 1.37e-02 1.91e-04h  1
#  104  1.8098097e+03 2.86e+01 6.46e+07  -1.0 2.18e+01   1.5 9.72e-04 3.09e-02f  1
#  105  1.8095075e+03 2.86e+01 6.48e+07  -1.0 3.91e+01   1.0 3.17e-03 9.83e-04h  1
#  106  1.8043755e+03 2.81e+01 6.21e+07  -1.0 2.82e+01   1.5 6.89e-05 1.53e-02f  1
#  107  1.8021694e+03 2.79e+01 6.83e+07  -1.0 1.49e+01   1.9 6.23e-02 6.10e-03h  1
#  108  1.8009896e+03 2.79e+01 6.79e+07  -1.0 1.01e+01   2.3 1.54e-03 3.17e-03h  1
#  109  1.8008664e+03 2.78e+01 8.06e+07  -1.0 1.58e+01   1.8 1.15e-01 3.47e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  1.7928001e+03 2.71e+01 7.62e+07  -1.0 2.72e+01   1.4 1.13e-03 2.52e-02h  1
#  111  1.7920977e+03 2.71e+01 7.73e+07  -1.0 4.85e+01   0.9 1.46e-02 2.38e-03h  1
#  112  1.7825776e+03 2.63e+01 7.18e+07  -1.0 2.90e+01   1.3 2.86e-04 3.06e-02f  1
#  113  1.7823174e+03 2.62e+01 7.39e+07  -1.0 7.86e+00   2.6 2.05e-02 7.40e-04h  1
#  114  1.7820430e+03 2.62e+01 7.77e+07  -1.0 1.07e+01   2.2 3.75e-02 7.82e-04h  1
#  115  1.7767244e+03 2.58e+01 7.78e+07  -1.0 1.73e+01   1.7 3.02e-02 1.61e-02h  1
#  116  1.7731509e+03 2.55e+01 7.57e+07  -1.0 4.29e+01   1.2 2.69e-05 1.21e-02f  1
#  117  1.7685202e+03 2.51e+01 7.41e+07  -1.0 8.18e+00   2.5 7.93e-03 1.34e-02h  1
#  118  1.7684819e+03 2.51e+01 8.05e+07  -1.0 1.15e+01   2.1 6.11e-02 1.14e-04h  1
#  119  1.7612566e+03 2.46e+01 7.73e+07  -1.0 1.98e+01   1.6 9.72e-03 2.31e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  1.7597959e+03 2.44e+01 7.64e+07  -1.0 1.45e+02   1.1 4.27e-06 5.23e-03f  1
#  121  1.7587128e+03 2.43e+01 7.68e+07  -1.0 8.51e+00   2.4 9.48e-03 3.26e-03h  1
#  122  1.7499432e+03 2.37e+01 7.52e+07  -1.0 1.28e+01   2.0 3.22e-02 2.71e-02h  1
#  123  1.7442213e+03 2.33e+01 7.24e+07  -1.0 8.66e+00   2.4 3.76e-03 1.77e-02h  1
#  124  1.7424633e+03 2.31e+01 7.52e+07  -1.0 1.54e+01   1.9 3.55e-02 5.70e-03h  1
#  125  1.7349956e+03 2.26e+01 7.55e+07  -1.0 8.89e+00   2.3 4.42e-02 2.37e-02h  1
#  126  1.7349001e+03 2.26e+01 7.92e+07  -1.0 6.56e+00   2.8 3.59e-02 3.15e-04h  1
#  127  1.7276300e+03 2.20e+01 8.52e+07  -1.0 9.12e+00   2.3 1.03e-01 2.36e-02h  1
#  128  1.7141257e+03 2.10e+01 7.77e+07  -1.0 1.58e+01   1.8 9.44e-03 4.67e-02h  1
#  129  1.7120312e+03 2.08e+01 7.77e+07  -1.0 3.38e+01   1.3 1.44e-02 8.17e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  1.7118550e+03 2.08e+01 7.78e+07  -1.0 3.86e+02   0.9 1.45e-03 6.56e-04h  1
#  131  1.7107557e+03 2.07e+01 7.85e+07  -1.0 3.68e+01   1.3 1.50e-02 4.33e-03h  1
#  132  1.7067803e+03 2.04e+01 7.59e+07  -1.0 1.84e+01   1.7 4.41e-04 1.46e-02h  1
#  133  1.7067077e+03 2.04e+01 7.82e+07  -1.0 9.79e+00   2.1 2.25e-02 2.59e-04h  1
#  134  1.7062157e+03 2.04e+01 7.82e+07  -1.0 7.14e+00   2.6 2.91e-03 1.76e-03h  1
#  135  1.7060580e+03 2.04e+01 8.13e+07  -1.0 1.06e+01   2.1 3.26e-02 5.70e-04h  1
#  136  1.6998014e+03 1.99e+01 7.74e+07  -1.0 2.18e+01   1.6 3.84e-03 2.39e-02h  1
#  137  1.6972076e+03 1.97e+01 7.61e+07  -1.0 5.81e+01   1.1 5.87e-03 1.07e-02h  1
#  138  1.6967438e+03 1.96e+01 7.58e+07  -1.0 2.40e+01   1.6 1.20e-04 1.83e-03h  1
#  139  1.6966377e+03 1.96e+01 7.63e+07  -1.0 5.39e+00   2.9 5.48e-03 4.05e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  1.6943835e+03 1.95e+01 7.56e+07  -1.0 7.85e+00   2.4 8.18e-03 8.34e-03h  1
#  141  1.6922309e+03 1.93e+01 7.71e+07  -1.0 1.29e+01   1.9 2.81e-02 8.18e-03h  1
#  142  1.6877024e+03 1.90e+01 7.45e+07  -1.0 2.94e+01   1.5 6.79e-03 1.84e-02h  1
#  143  1.6869162e+03 1.89e+01 7.39e+07  -1.0 1.83e+01   1.9 2.31e-04 3.07e-03h  1
#  144  1.6863937e+03 1.89e+01 7.44e+07  -1.0 8.40e+00   2.3 7.80e-03 2.00e-03h  1
#  145  1.6863807e+03 1.89e+01 7.54e+07  -1.0 5.90e+00   2.7 9.45e-03 5.04e-05h  1
#  146  1.6835120e+03 1.87e+01 7.43e+07  -1.0 8.81e+00   2.3 8.44e-03 1.10e-02h  1
#  147  1.6813325e+03 1.85e+01 7.34e+07  -1.0 1.65e+01   1.8 6.79e-03 8.73e-03h  1
#  148  1.6808169e+03 1.85e+01 7.33e+07  -1.0 4.21e+01   1.3 2.87e-03 2.19e-03h  1
#  149  1.6799274e+03 1.84e+01 7.27e+07  -1.0 2.17e+01   1.7 5.62e-05 3.62e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  1.6797129e+03 1.84e+01 7.32e+07  -1.0 9.54e+00   2.1 6.21e-03 8.44e-04h  1
#  151  1.6797030e+03 1.84e+01 7.42e+07  -1.0 6.56e+00   2.6 9.10e-03 3.90e-05h  1
#  152  1.6768767e+03 1.82e+01 7.25e+07  -1.0 1.00e+01   2.1 2.86e-03 1.12e-02h  1
#  153  1.6760448e+03 1.81e+01 7.24e+07  -1.0 2.17e+01   1.6 5.75e-03 3.47e-03h  1
#  154  1.6757524e+03 1.81e+01 7.92e+07  -1.0 1.05e+01   2.0 6.59e-02 1.18e-03h  1
#  155  1.6711073e+03 1.77e+01 7.60e+07  -1.0 2.40e+01   1.6 2.30e-03 1.96e-02h  1
#  156  1.6702996e+03 1.77e+01 7.59e+07  -1.0 8.05e+01   1.1 5.19e-03 3.45e-03h  1
#  157  1.6652418e+03 1.73e+01 7.20e+07  -1.0 2.68e+01   1.5 9.47e-05 2.18e-02h  1
#  158  1.6645107e+03 1.72e+01 7.18e+07  -1.0 5.00e+00   2.8 2.96e-03 3.15e-03h  1
#  159  1.6645018e+03 1.72e+01 7.27e+07  -1.0 7.49e+00   2.4 8.77e-03 3.74e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  1.6621586e+03 1.71e+01 7.18e+07  -1.0 1.35e+01   1.9 8.90e-03 9.94e-03h  1
#  161  1.6618876e+03 1.70e+01 7.17e+07  -1.0 3.31e+01   1.4 3.27e-04 1.20e-03h  1
#  162  1.6618679e+03 1.70e+01 7.22e+07  -1.0 5.39e+00   2.7 5.51e-03 8.51e-05h  1
#  163  1.6584067e+03 1.68e+01 7.12e+07  -1.0 8.21e+00   2.3 1.48e-02 1.47e-02h  1
#  164  1.6568078e+03 1.67e+01 7.14e+07  -1.0 1.60e+01   1.8 1.35e-02 6.99e-03h  1
#  165  1.6567462e+03 1.67e+01 7.22e+07  -1.0 8.57e+00   2.2 8.06e-03 2.67e-04h  1
#  166  1.6520314e+03 1.63e+01 6.89e+07  -1.0 1.76e+01   1.7 3.61e-03 2.08e-02h  1
#  167  1.6519910e+03 1.63e+01 7.12e+07  -1.0 8.93e+00   2.2 2.16e-02 1.78e-04h  1
#  168  1.6496345e+03 1.61e+01 6.99e+07  -1.0 1.96e+01   1.7 5.74e-03 1.06e-02h  1
#  169  1.6493996e+03 1.61e+01 6.97e+07  -1.0 6.17e+01   1.2 9.21e-06 1.06e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  1.6492073e+03 1.61e+01 7.04e+07  -1.0 6.20e+00   2.5 7.78e-03 8.65e-04h  1
#  171  1.6448568e+03 1.58e+01 7.10e+07  -1.0 1.01e+01   2.1 3.78e-02 1.95e-02h  1
#  172  1.6424094e+03 1.56e+01 6.91e+07  -1.0 3.80e+01   1.6 9.77e-04 1.14e-02h  1
#  173  1.6421780e+03 1.56e+01 7.06e+07  -1.0 4.40e+00   2.9 1.58e-02 1.12e-03h  1
#  174  1.6385812e+03 1.53e+01 6.92e+07  -1.0 6.72e+00   2.4 1.39e-02 1.67e-02h  1
#  175  1.6358230e+03 1.51e+01 6.69e+07  -1.0 1.69e+01   2.0 1.54e-04 1.30e-02h  1
#  176  1.6340664e+03 1.50e+01 6.83e+07  -1.0 6.98e+00   2.4 2.62e-02 8.35e-03h  1
#  177  1.6324570e+03 1.49e+01 7.05e+07  -1.0 4.70e+00   2.8 3.30e-02 7.98e-03h  1
#  178  1.6324153e+03 1.49e+01 7.23e+07  -1.0 7.34e+00   2.3 1.69e-02 2.02e-04h  1
#  179  1.6268287e+03 1.45e+01 6.86e+07  -1.0 1.48e+01   1.9 1.02e-02 2.70e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  1.6262391e+03 1.44e+01 6.81e+07  -1.0 4.19e+01   1.4 1.83e-04 2.85e-03h  1
#  181  1.6261630e+03 1.44e+01 6.93e+07  -1.0 5.03e+00   2.7 1.16e-02 3.87e-04h  1
#  182  1.6241224e+03 1.43e+01 6.76e+07  -1.0 8.04e+00   2.2 1.60e-03 1.01e-02h  1
#  183  1.6219783e+03 1.41e+01 6.58e+07  -1.0 1.79e+01   1.8 5.54e-04 1.07e-02h  1
#  184  1.6218526e+03 1.41e+01 6.94e+07  -1.0 8.53e+00   2.2 3.30e-02 6.31e-04h  1
#  185  1.6201046e+03 1.40e+01 6.79e+07  -1.0 1.99e+01   1.7 3.09e-04 8.83e-03h  1
#  186  1.6198617e+03 1.40e+01 6.80e+07  -1.0 3.66e+00   3.0 3.83e-03 1.33e-03h  1
#  187  1.6197928e+03 1.40e+01 6.84e+07  -1.0 5.69e+00   2.6 3.96e-03 3.57e-04h  1
#  188  1.6183668e+03 1.39e+01 6.78e+07  -1.0 1.00e+01   2.1 6.34e-03 7.27e-03h  1
#  189  1.6177962e+03 1.38e+01 6.74e+07  -1.0 2.45e+01   1.6 9.45e-04 2.91e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  1.6177757e+03 1.38e+01 6.84e+07  -1.0 4.00e+00   2.9 9.06e-03 1.12e-04h  1
#  191  1.6140847e+03 1.36e+01 6.60e+07  -1.0 6.26e+00   2.5 9.23e-03 1.92e-02h  1
#  192  1.6117623e+03 1.34e+01 6.55e+07  -1.0 1.22e+01   2.0 1.52e-02 1.21e-02h  1
#  193  1.6117168e+03 1.34e+01 6.81e+07  -1.0 6.52e+00   2.4 2.32e-02 2.43e-04h  1
#  194  1.6092705e+03 1.32e+01 6.71e+07  -1.0 1.33e+01   1.9 1.23e-02 1.29e-02h  1
#  195  1.6080394e+03 1.31e+01 6.60e+07  -1.0 3.67e+01   1.4 2.08e-05 6.29e-03h  1
#  196  1.6073323e+03 1.31e+01 6.66e+07  -1.0 4.45e+00   2.8 1.13e-02 3.97e-03h  1
#  197  1.6072687e+03 1.31e+01 6.84e+07  -1.0 7.19e+00   2.3 1.64e-02 3.46e-04h  1
#  198  1.6038631e+03 1.28e+01 6.54e+07  -1.0 1.59e+01   1.8 3.17e-03 1.83e-02h  1
#  199  1.6024005e+03 1.27e+01 6.86e+07  -1.0 7.54e+00   2.3 4.06e-02 8.09e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  1.5997184e+03 1.26e+01 6.61e+07  -1.0 1.77e+01   1.8 1.54e-03 1.47e-02h  1
#  201  1.5980956e+03 1.24e+01 6.59e+07  -1.0 8.10e+00   2.2 1.31e-02 9.18e-03h  1
#  202  1.5965325e+03 1.23e+01 6.94e+07  -1.0 5.00e+00   2.6 4.55e-02 9.16e-03h  1
#  203  1.5941778e+03 1.22e+01 6.71e+07  -1.0 8.98e+00   2.1 4.11e-04 1.36e-02h  1
#  204  1.5936740e+03 1.21e+01 7.20e+07  -1.0 5.22e+00   2.6 4.96e-02 3.01e-03h  1
#  205  1.5934879e+03 1.21e+01 7.50e+07  -1.0 3.43e+00   3.0 3.02e-02 1.19e-03h  1
#  206  1.5865112e+03 1.16e+01 7.39e+07  -1.0 5.51e+00   2.5 6.14e-02 4.19e-02h  1
#  207  1.5829340e+03 1.13e+01 7.17e+07  -1.0 1.11e+01   2.0 1.53e-02 2.17e-02h  1
#  208  1.5815589e+03 1.13e+01 7.09e+07  -1.0 2.96e+01   1.6 5.62e-03 7.87e-03h  1
#  209  1.5789456e+03 1.11e+01 6.90e+07  -1.0 1.22e+01   2.0 9.25e-03 1.62e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  1.5788244e+03 1.11e+01 7.28e+07  -1.0 5.95e+00   2.4 3.60e-02 7.83e-04h  1
#  211  1.5775671e+03 1.10e+01 7.18e+07  -1.0 1.33e+01   1.9 3.96e-03 7.86e-03h  1
#  212  1.5732341e+03 1.07e+01 7.24e+07  -1.0 6.29e+00   2.4 5.31e-02 2.82e-02h  1
#  213  1.5716176e+03 1.06e+01 7.11e+07  -1.0 1.47e+01   1.9 4.49e-03 1.04e-02h  1
#  214  1.5702780e+03 1.05e+01 7.26e+07  -1.0 6.65e+00   2.3 2.89e-02 8.98e-03h  1
#  215  1.5686797e+03 1.03e+01 7.31e+07  -1.0 4.07e+00   2.7 2.46e-02 1.13e-02h  1
#  216  1.5653231e+03 1.01e+01 6.91e+07  -1.0 8.79e+00   2.3 1.07e-04 2.28e-02h  1
#  217  1.5648648e+03 1.01e+01 7.62e+07  -1.0 4.24e+00   2.7 7.03e-02 3.32e-03h  1
#  218  1.5596181e+03 9.67e+00 7.82e+07  -1.0 2.70e+00   3.1 9.14e-02 4.11e-02h  1
#  219  1.5595611e+03 9.66e+00 7.97e+07  -1.0 4.48e+00   2.6 1.59e-02 4.27e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  1.5582636e+03 9.57e+00 7.87e+07  -1.0 9.21e+00   2.2 6.63e-03 9.22e-03h  1
#  221  1.5582299e+03 9.57e+00 8.15e+07  -1.0 4.73e+00   2.6 2.85e-02 2.53e-04h  1
#  222  1.5533094e+03 9.23e+00 7.68e+07  -1.0 1.02e+01   2.1 1.63e-02 3.51e-02h  1
#  223  1.5515604e+03 9.13e+00 7.48e+07  -1.0 2.82e+01   1.6 2.16e-05 1.14e-02h  1
#  224  1.5492359e+03 8.95e+00 8.03e+07  -1.0 3.04e+00   3.0 8.65e-02 1.93e-02h  1
#  225  1.5490666e+03 8.94e+00 9.38e+07  -1.0 5.21e+00   2.5 1.39e-01 1.33e-03h  1
#  226  1.5421739e+03 8.48e+00 8.55e+07  -1.0 1.24e+01   2.0 1.05e-02 5.13e-02h  1
#  227  1.5410096e+03 8.42e+00 8.43e+07  -1.0 5.96e+01   1.5 1.02e-05 6.86e-03h  1
#  228  1.5390342e+03 8.28e+00 8.73e+07  -1.0 3.25e+00   2.9 6.45e-02 1.74e-02h  1
#  229  1.5382100e+03 8.22e+00 8.64e+07  -1.0 1.39e+01   2.4 3.45e-03 6.93e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230  1.5344280e+03 7.94e+00 9.13e+07  -1.0 3.42e+00   2.8 1.19e-01 3.37e-02h  1
#  231  1.5279843e+03 7.43e+00 9.92e+07  -1.0 2.07e+00   3.2 2.23e-01 6.50e-02h  1
#  232  1.5241955e+03 7.16e+00 9.71e+07  -1.0 3.60e+00   2.8 5.56e-02 3.63e-02h  1
#  233  1.5237060e+03 7.12e+00 1.55e+08  -1.0 2.14e+00   3.2 7.20e-01 5.32e-03h  1
#  234  1.5087198e+03 6.06e+00 1.30e+08  -1.0 3.80e+00   2.7 8.02e-02 1.49e-01h  1
#  235  1.5065501e+03 5.93e+00 1.28e+08  -1.0 8.95e+00   2.2 4.00e-02 2.24e-02h  1
#  236  1.5038832e+03 5.79e+00 1.24e+08  -1.0 2.69e+01   1.8 8.23e-05 2.28e-02h  1
#  237  1.5035103e+03 5.76e+00 1.34e+08  -1.0 2.19e+00   3.1 1.92e-01 4.80e-03h  1
#  238  1.4967328e+03 5.31e+00 1.20e+08  -1.0 4.39e+00   2.6 2.00e-02 7.94e-02h  1
#  239  1.4936539e+03 5.08e+00 1.38e+08  -1.0 2.25e+00   3.0 4.37e-01 4.24e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  1.4880076e+03 4.71e+00 1.26e+08  -1.0 8.92e+00   2.6 2.01e-02 7.30e-02h  1
#  241  1.4845869e+03 4.47e+00 1.39e+08  -1.0 2.32e+00   3.0 4.22e-01 5.17e-02h  1
#  242  1.4757565e+03 3.75e+00 1.50e+08  -1.0 1.26e+00   3.4 1.00e+00 1.59e-01h  1
#  243  1.4719246e+03 3.50e+00 1.43e+08  -1.0 2.49e+00   2.9 1.66e-01 6.69e-02h  1
#  244  1.4686159e+03 3.26e+00 1.52e+08  -1.0 1.31e+00   3.4 6.02e-01 7.06e-02h  1
#  245  1.4673121e+03 3.17e+00 1.51e+08  -1.0 2.72e+00   2.9 1.53e-01 2.52e-02h  1
#  246  1.4573220e+03 2.46e+00 1.38e+08  -1.0 1.39e+00   3.3 1.00e+00 2.26e-01h  1
#  247  1.4510239e+03 2.10e+00 1.15e+08  -1.0 3.96e+00   2.8 7.51e-02 1.46e-01h  1
#  248  1.4480479e+03 1.90e+00 1.07e+08  -1.0 1.38e+00   3.3 1.30e-01 9.26e-02h  1
#  249  1.4455132e+03 1.77e+00 9.75e+07  -1.0 1.11e+01   2.8 4.68e-02 7.14e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250  1.4453607e+03 1.76e+00 1.43e+08  -1.0 1.81e+00   3.2 5.79e-01 5.41e-03h  1
#  251  1.4423894e+03 1.53e+00 1.55e+08  -1.0 6.94e-01   3.6 1.00e+00 1.31e-01h  1
#  252  1.4401015e+03 1.39e+00 1.45e+08  -1.0 2.21e+00   3.2 2.26e-01 8.85e-02h  1
#  253  1.4377248e+03 1.22e+00 1.45e+08  -1.0 7.73e-01   3.6 6.53e-01 1.23e-01h  1
#  254  1.4356758e+03 1.11e+00 1.40e+08  -1.0 3.05e+00   3.1 3.53e-01 9.25e-02h  1
#  255  1.4333705e+03 1.00e+00 1.53e+08  -1.0 9.44e-01   3.5 1.00e+00 1.41e-01h  1
#  256  1.4329894e+03 1.00e+00 1.54e+08  -1.0 4.83e+00   3.0 1.70e-01 2.05e-02h  1
#  257  1.4329784e+03 1.00e+00 1.56e+08  -1.0 1.11e+01   2.6 8.57e-02 4.33e-04h  1
#  258  1.4318497e+03 1.00e+00 1.53e+08  -1.0 2.14e+01   2.1 7.75e-02 2.88e-02h  1
#  259  1.4313089e+03 1.00e+00 1.52e+08  -1.0 9.18e+00   2.5 1.33e-01 2.14e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260  1.4308892e+03 1.00e+00 1.51e+08  -1.0 2.33e+01   2.0 4.03e-02 1.11e-02h  1
#  261  1.4292724e+03 1.00e+00 1.40e+08  -1.0 1.02e+01   2.5 3.31e-03 6.44e-02h  1
#  262  1.4291213e+03 1.00e+00 1.41e+08  -1.0 2.99e+01   2.0 4.11e-02 4.12e-03h  1
#  263  1.4282727e+03 1.00e+00 1.37e+08  -1.0 1.14e+01   2.4 6.53e-02 3.50e-02h  1
#  264  1.4279568e+03 1.00e+00 1.35e+08  -1.0 3.81e+01   1.9 8.31e-04 8.48e-03h  1
#  265  1.4275571e+03 1.00e+00 1.35e+08  -1.0 1.26e+01   2.4 4.99e-02 1.67e-02h  1
#  266  1.4272674e+03 1.00e+00 1.34e+08  -1.0 5.16e+01   1.9 1.04e-02 7.57e-03h  1
#  267  1.4269219e+03 1.00e+00 1.35e+08  -1.0 1.39e+01   2.3 8.88e-02 1.45e-02h  1
#  268  1.4266890e+03 1.00e+00 1.35e+08  -1.0 7.62e+01   1.8 1.46e-02 5.91e-03h  1
#  269  1.4258596e+03 1.00e+00 1.32e+08  -1.0 1.53e+01   2.3 8.48e-02 3.50e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270  1.4257320e+03 1.00e+00 1.32e+08  -1.0 1.36e+02   1.8 6.00e-03 3.40e-03h  1
#  271  1.4252106e+03 1.00e+00 1.31e+08  -1.0 1.68e+01   2.2 7.10e-02 2.26e-02h  1
#  272  1.4251944e+03 1.00e+00 1.31e+08  -1.0 3.77e+02   1.7 1.59e-03 4.73e-04h  1
#  273  1.4245903e+03 1.00e+00 1.30e+08  -1.0 1.84e+01   2.2 8.02e-02 2.63e-02h  1
#  274  1.4237448e+03 1.00e+00 1.21e+08  -1.0 7.72e+00   2.6 7.00e-03 5.19e-02h  1
#  275  1.4237412e+03 1.00e+00 1.36e+08  -1.0 8.81e-01   3.9 2.51e-01 5.39e-04h  1
#  276  1.4235792e+03 1.00e+00 1.59e+08  -1.0 1.14e+00   3.4 6.12e-01 1.77e-02h  1
#  277  1.4219556e+03 1.00e+00 1.41e+08  -1.0 3.39e+00   3.0 3.83e-01 1.40e-01h  1
#  278  1.4210741e+03 1.00e+00 1.30e+08  -1.0 9.78e+00   2.5 4.09e-03 6.13e-02h  1
#  279  1.4209305e+03 1.00e+00 1.32e+08  -1.0 3.01e+01   2.0 5.74e-02 7.87e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280  1.4207545e+03 1.00e+00 1.34e+08  -1.0 1.08e+01   2.4 1.05e-01 1.28e-02h  1
#  281  1.4202888e+03 1.00e+00 1.30e+08  -1.0 3.72e+01   2.0 1.75e-02 2.72e-02h  1
#  282  1.4202397e+03 1.00e+00 1.30e+08  -1.0 1.19e+01   2.4 1.18e-02 3.67e-03h  1
#  283  1.4201809e+03 1.00e+00 1.30e+08  -1.0 4.67e+01   1.9 3.21e-05 3.61e-03h  1
#  284  1.4201809e+03 1.00e+00 1.30e+08  -1.0 4.04e+01   3.2 4.42e-03 1.34e-05h  1
#  285  1.4196229e+03 1.00e+00 1.20e+08  -1.0 5.34e+00   2.8 1.80e-03 5.61e-02h  1
#  286  1.4196201e+03 1.00e+00 1.64e+08  -1.0 3.59e-01   4.1 7.48e-01 7.22e-04h  1
#  287  1.4186789e+03 1.00e+00 1.38e+08  -1.0 7.73e-01   3.6 3.66e-01 1.74e-01h  1
#  288  1.4180563e+03 1.00e+00 1.27e+08  -1.0 2.37e+00   3.1 1.58e-01 9.94e-02h  1
#  289  1.4171241e+03 1.00e+00 1.17e+08  -1.0 6.92e+00   2.7 1.74e-01 1.08e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290  1.4170100e+03 1.00e+00 1.15e+08  -1.0 1.84e+01   2.2 4.77e-04 1.00e-02h  1
#  291  1.4170072e+03 1.00e+00 1.40e+08  -1.0 1.02e+00   3.5 4.02e-01 7.70e-04h  1
#  292  1.4158570e+03 1.00e+00 1.04e+08  -1.0 3.01e+00   3.0 5.04e-02 2.14e-01h  1
#  293  1.4158400e+03 1.00e+00 1.46e+08  -1.0 1.16e+00   3.5 5.82e-01 5.47e-03h  1
#  294  1.4151770e+03 1.00e+00 1.23e+08  -1.0 3.44e+00   3.0 7.02e-02 1.42e-01h  1
#  295  1.4150411e+03 1.00e+00 1.20e+08  -1.0 9.83e+00   2.5 1.52e-04 1.92e-02h  1
#  296  1.4150055e+03 1.00e+00 1.61e+08  -1.0 4.94e-01   3.8 7.59e-01 1.89e-02h  1
#  297  1.4136801e+03 1.00e+00 7.56e+07  -1.0 1.49e+00   3.4 8.03e-03 4.79e-01h  1
#  298  1.4130628e+03 1.00e+00 3.43e+07  -1.0 5.84e-01   3.8 5.67e-01 5.59e-01h  1
#  299  1.4127598e+03 1.00e+00 1.71e+07  -1.0 2.30e-01   4.2 6.65e-01 8.26e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300  1.4124544e+03 1.00e+00 7.87e+07  -1.0 7.44e-01   3.7 1.22e-01 4.78e-01h  1
#  301  1.4123102e+03 1.00e+00 7.41e+07  -1.0 2.90e-01   4.2 5.28e-01 7.35e-01h  1
#  302  1.4120630e+03 1.00e+00 1.33e+08  -1.0 9.15e-01   3.7 1.31e-02 3.47e-01h  1
#  303  1.4118908e+03 1.00e+00 1.59e+08  -1.0 3.51e-01   4.1 3.95e-01 8.33e-01h  1
#  304  1.4118306e+03 1.00e+00 1.44e+08  -1.0 2.77e+00   3.6 6.19e-02 3.51e-02h  3
#  305  1.4117101e+03 1.00e+00 2.17e+08  -1.0 4.17e-01   4.1 3.65e-02 4.73e-01h  1
#  306  1.4116780e+03 1.00e+00 7.62e+07  -1.0 1.61e-01   4.5 5.31e-01 3.89e-01h  1
#  307  1.4115755e+03 1.00e+00 2.54e+07  -1.0 4.94e-01   4.0 6.46e-01 3.52e-01h  1
#  308  1.4114835e+03 1.00e+00 5.07e+03  -1.0 1.89e-01   4.4 1.00e+00 1.00e+00h  1
#  309  1.4113552e+03 1.00e+00 3.48e+07  -1.7 6.11e-01   4.0 2.29e-01 3.59e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310  1.4112936e+03 1.00e+00 7.74e+07  -1.7 2.35e-01   4.4 3.58e-01 5.64e-01h  1
#  311  1.4111568e+03 1.00e+00 7.59e+07  -1.7 8.11e-01   3.9 2.45e-01 3.10e-01h  1
#  312  1.4110551e+03 1.00e+00 1.84e+08  -1.7 2.80e-01   4.3 3.73e-01 8.83e-01h  1
#  313  1.4109795e+03 1.00e+00 2.01e+08  -1.7 1.73e+00   3.8 6.15e-03 7.54e-02h  1
#  314  1.4109762e+03 1.00e+00 3.98e+07  -1.7 3.49e-01   4.3 3.59e-01 2.55e-02h  1
#  315  1.4109761e+03 1.00e+00 3.98e+07  -1.7 1.04e+00   3.8 3.78e-04 3.78e-04s 11
#  316  1.4109457e+03 1.00e+00 9.18e+06  -1.7 3.01e+00   3.3 1.60e-01 0.00e+00S 11
#  317  1.4109018e+03 1.00e+00 2.42e+07  -1.7 8.67e+00   2.8 7.68e-02 1.79e-02h  1
#  318  1.4109010e+03 1.00e+00 2.55e+07  -1.7 3.98e+01   2.4 6.55e-03 9.16e-04h  3
#  319  1.4108663e+03 1.00e+00 3.23e+07  -1.7 9.66e+00   2.8 4.40e-02 1.46e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320  1.4108661e+03 1.00e+00 3.23e+07  -1.7 5.42e+01   2.3 3.69e-04 2.15e-04h  3
#  321  1.4108505e+03 1.00e+00 3.70e+07  -1.7 1.08e+01   2.7 2.75e-02 6.42e-03h  1
#  322  1.4108454e+03 1.00e+00 3.70e+07  -1.7 1.46e+02   2.3 6.79e-04 6.79e-04s 14
#  323  1.4107241e+03 1.00e+00 3.51e+07  -1.7 1.20e+01   2.7 5.09e-02 5.09e-02s 14
#  324  1.4106928e+03 1.00e+00 3.44e+07  -1.7 4.71e+00   3.1 2.22e-02 2.22e-02s 14
#  325  1.4106600e+03 1.00e+00 3.38e+07  -1.7 1.32e+01   2.6 1.67e-02 1.67e-02s 14
#  326  1.4106449e+03 1.00e+00 3.34e+07  -1.7 5.26e+00   3.1 1.08e-02 1.08e-02s 14
#  327  1.4106252e+03 1.00e+00 3.30e+07  -1.7 1.54e+01   2.6 1.33e-02 1.33e-02s 14
#  328  1.4105521e+03 1.00e+00 3.13e+07  -1.7 5.88e+00   3.0 5.10e-02 5.10e-02s 14
#  329  1.4105512e+03 1.00e+00 3.13e+07  -1.7 1.83e+01   2.5 1.01e-03 1.01e-03s 14
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330  1.4105248e+03 1.00e+00 3.07e+07  -1.7 6.57e+00   3.0 1.85e-02 1.85e-02s 14
#  331  1.4105222e+03 1.00e+00 3.05e+07  -1.7 2.20e+01   2.5 6.75e-03 6.75e-03s 14
#  332  1.4104673e+03 1.00e+00 2.93e+07  -1.7 7.32e+00   2.9 3.89e-02 3.89e-02s 14
#  333r 1.4104673e+03 1.00e+00 1.00e+03  -0.0 0.00e+00   2.4 0.00e+00 0.00e+00R  1
#  334r 3.3842873e+03 1.46e+00 1.43e+03  -0.0 2.91e+02    -  8.69e-02 1.94e-01f  1
#  335r 4.2089791e+03 1.43e+00 1.10e+03  -0.0 9.52e+01    -  2.59e-01 3.79e-01f  1
#  336r 4.4429269e+03 1.07e+00 7.48e+02  -0.0 2.47e+01    -  2.19e-01 2.86e-01f  1
#  337r 4.6305272e+03 1.00e+00 4.97e+02  -0.0 1.78e+01    -  2.70e-01 3.71e-01f  1
#  338r 4.7726602e+03 1.00e+00 3.57e+02  -0.0 4.18e+01    -  3.58e-01 5.11e-01f  1
#  339r 4.8724618e+03 1.00e+00 2.25e+02  -0.0 6.35e+00  -2.0 5.45e-01 8.54e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340r 4.8892434e+03 1.00e+00 2.23e+02  -0.0 1.25e+01  -2.5 5.68e-01 1.00e+00f  1
#  341r 4.8874728e+03 1.00e+00 1.92e+02  -0.0 4.51e+01    -  3.77e-01 2.44e-01f  1
#  342r 4.8835816e+03 3.30e+00 5.77e+02  -0.0 3.82e+01    -  2.80e-01 1.00e+00f  1
#  343r 4.8742285e+03 2.68e+00 1.44e+02  -0.0 3.46e+01    -  3.79e-01 7.18e-01f  1
#  344r 4.8693802e+03 1.33e+00 2.14e+02  -0.0 2.71e+01    -  2.91e-01 5.21e-01f  1
#  345r 4.8600447e+03 1.76e+00 1.83e+02  -0.0 1.50e+02    -  7.80e-02 1.44e-01f  1
#  346r 4.8714434e+03 1.71e+00 1.15e+02  -0.0 1.75e+01    -  7.67e-01 1.00e+00f  1
#  347r 4.8742535e+03 1.00e+00 7.15e+01  -0.0 2.77e+01    -  5.28e-01 1.00e+00f  1
#  348r 4.8803708e+03 1.00e+00 1.91e+01  -0.0 7.71e+00    -  8.25e-01 1.00e+00f  1
#  349r 3.4866690e+03 1.00e+00 2.06e+01  -0.7 2.15e+01    -  9.29e-01 8.60e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350r 3.4909644e+03 1.00e+00 2.18e+01  -0.7 2.93e+01  -3.0 1.08e-01 9.23e-02f  1
#  351r 3.5077103e+03 1.00e+00 4.69e+01  -0.7 1.50e+01  -2.5 4.38e-01 3.94e-01f  1
#  352r 3.5218118e+03 1.00e+00 1.28e+02  -0.7 1.42e+01  -3.0 6.17e-01 3.92e-01f  1
#  353r 3.5484292e+03 1.00e+00 3.89e-01  -0.7 7.05e+00  -2.6 1.00e+00 1.00e+00f  1
#  354r 3.1896052e+03 1.00e+00 7.53e+01  -2.1 1.48e+01  -3.1 4.55e-01 2.87e-01f  1
#  355r 3.0853814e+03 1.00e+00 7.01e+01  -2.1 3.97e+00  -1.7 4.12e-01 3.42e-01f  1
#  356r 3.0055931e+03 1.00e+00 5.24e+01  -2.1 1.06e+01  -2.2 1.78e-01 2.05e-01f  1
#  357r 2.8575943e+03 1.00e+00 2.58e+01  -2.1 4.31e+00  -1.8 4.06e-01 4.35e-01f  1
#  358r 2.7451522e+03 1.00e+00 6.91e+01  -2.1 1.06e+01  -2.3 1.93e-01 2.99e-01f  1
#  359r 2.7194031e+03 1.00e+00 7.91e+01  -2.1 2.26e+01  -2.7 5.74e-02 7.18e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360r 2.6504405e+03 1.00e+00 8.11e+01  -2.1 1.01e+01  -2.3 1.87e-01 2.11e-01f  1
#  361r 2.6354661e+03 1.00e+00 4.71e+02  -2.1 2.31e+01  -2.8 2.01e-01 4.63e-02f  1
#  362r 2.5933971e+03 1.00e+00 4.64e+02  -2.1 9.94e+00  -2.4 4.21e-01 1.35e-01f  1
#  363r 2.4577398e+03 1.00e+00 2.14e+02  -2.1 4.20e+00  -1.9 6.76e-01 4.87e-01f  1
#  364r 2.4201655e+03 1.00e+00 4.02e+02  -2.1 1.17e+01  -2.4 3.47e-01 1.53e-01f  1
#  365r 2.3634626e+03 1.00e+00 3.83e+02  -2.1 2.01e+01  -2.9 5.80e-02 2.39e-01f  1
#  366r 2.3387967e+03 1.00e+00 3.02e+02  -2.1 8.39e+00  -2.5 4.30e-01 1.41e-01f  1
#  367r 2.3110132e+03 1.00e+00 2.69e+02  -2.1 2.32e+01  -2.9 8.04e-02 1.64e-01f  1
#  368r 2.2821858e+03 1.00e+00 2.19e+02  -2.1 8.96e+00  -2.5 4.12e-01 2.13e-01f  1
#  369r 2.2650235e+03 1.00e+00 2.50e+02  -2.1 2.51e+01  -3.0 2.40e-01 1.44e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  370r 2.2334598e+03 1.00e+00 1.60e+02  -2.1 9.35e+00  -2.6 2.36e-01 3.24e-01f  1
#  371r 2.2207878e+03 1.00e+00 3.45e+02  -2.1 2.61e+01  -3.0 3.61e-01 1.72e-01f  1
#  372r 2.2143145e+03 1.00e+00 2.26e+02  -2.1 5.71e+01  -3.5 2.30e-02 1.04e-01f  1
#  373r 2.1857366e+03 1.00e+00 9.43e+01  -2.1 3.83e+00  -2.2 5.22e-01 6.07e-01f  1
#  374r 2.1798343e+03 1.00e+00 1.01e+02  -2.1 1.05e+01  -2.7 3.76e-01 2.21e-01f  1
#  375r 2.1703693e+03 1.00e+00 2.50e+02  -2.1 2.65e+01  -3.1 1.80e-01 4.25e-01f  1
#  376r 2.1684788e+03 1.00e+00 2.02e+02  -2.1 1.01e+01  -2.7 1.72e-01 1.50e-01f  1
#  377r 2.1632308e+03 1.00e+00 1.44e+02  -2.1 3.94e+00  -2.3 8.14e-01 5.43e-01f  1
#  378r 2.1620583e+03 1.00e+00 2.27e+02  -2.1 1.05e+01  -2.8 3.94e-01 1.96e-01f  1
#  379r 2.1608169e+03 1.00e+00 2.85e+02  -2.1 3.63e+01  -3.2 2.69e-02 2.82e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  380r 2.1607740e+03 1.00e+00 2.50e+02  -2.1 5.17e+01  -3.7 1.44e-01 5.34e-02f  1
#  381r 2.1608360e+03 1.00e+00 2.44e+02  -2.1 1.38e+04  -4.2 1.75e-04 9.72e-04f  1
#  382r 2.1608712e+03 1.00e+00 2.27e+02  -2.1 2.10e+02  -3.8 5.47e-02 4.56e-02f  1
#  383r 2.1604837e+03 1.00e+00 1.79e+02  -2.1 3.10e+01  -3.3 2.29e-01 1.91e-01f  1
#  384r 2.1593554e+03 1.00e+00 1.07e+02  -2.1 1.37e+01  -2.9 6.19e-01 4.89e-01f  1
#  385r 2.1593993e+03 1.00e+00 2.09e+02  -2.1 3.46e+01  -3.4 3.19e-01 1.05e-01f  1
#  386r 2.1601691e+03 1.00e+00 1.52e+02  -2.1 6.94e+01  -3.9 3.26e-01 2.11e-01f  1
#  387r 2.1642072e+03 1.67e+00 8.26e+01  -2.1 1.44e+02  -4.4 2.65e-01 4.17e-01f  1
#  388r 2.1678394e+03 2.21e+00 9.15e+01  -2.1 2.67e+02    -  1.00e-01 1.48e-01f  1
#  389r 2.1713111e+03 2.37e+00 1.05e+02  -2.1 1.94e+02    -  1.14e-01 1.68e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  390r 2.1779915e+03 2.38e+00 1.80e+02  -2.1 1.62e+02    -  2.02e-01 3.26e-01f  1
#  391r 2.1835466e+03 1.45e+00 2.78e+02  -2.1 1.47e+02    -  1.15e-01 3.91e-01f  1
#  392r 2.1891572e+03 1.00e+00 1.57e+02  -2.1 6.41e+01    -  7.28e-01 5.61e-01f  1
#  393r 2.1936533e+03 1.00e+00 2.96e+01  -2.1 2.36e+01    -  9.12e-01 1.00e+00h  1
#  394r 2.1936795e+03 1.00e+00 1.45e-02  -2.1 1.77e+00    -  1.00e+00 1.00e+00h  1
#  395r 2.0278190e+03 1.00e+00 1.57e+02  -4.7 7.76e+00    -  7.53e-01 3.17e-01f  1
#  396r 2.0237040e+03 1.00e+00 1.42e+02  -4.7 3.05e+01  -3.0 5.44e-02 6.58e-02f  1
#  397r 2.0206632e+03 1.00e+00 4.38e+02  -4.7 2.35e+00  -1.7 3.60e-01 9.14e-02f  1
#  398r 2.0124621e+03 1.00e+00 1.63e+02  -4.7 9.35e-01  -1.3 1.67e-01 4.46e-01f  1
#  399r 2.0091697e+03 1.00e+00 2.64e+02  -4.7 2.45e+00  -1.7 2.79e-01 7.94e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400r 2.0008823e+03 1.00e+00 2.93e+02  -4.7 6.68e+00  -2.2 1.33e-01 9.68e-02f  1
#  401r 1.9952612e+03 1.00e+00 4.38e+02  -4.7 1.72e+01  -2.7 1.53e-01 4.33e-02f  1
#  402r 1.9834504e+03 1.00e+00 3.92e+02  -4.7 3.33e+01  -3.2 5.70e-02 6.80e-02f  1
#  403r 1.9761412e+03 1.00e+00 4.04e+02  -4.7 9.49e+01  -3.7 5.01e-02 3.29e-02f  1
#  404r 1.9637954e+03 1.00e+00 3.95e+02  -4.7 3.66e+01  -3.2 8.47e-02 6.95e-02f  1
#  405r 1.9597283e+03 1.00e+00 3.93e+02  -4.7 1.04e+02  -3.7 2.85e-02 1.82e-02f  1
#  406r 1.9414314e+03 1.00e+00 3.90e+02  -4.7 1.08e+03  -4.2 1.51e-02 1.06e-02f  1
#  407r 1.9399425e+03 1.00e+00 4.38e+02  -4.7 1.11e+02  -3.8 5.94e-02 8.44e-03f  1
#  408r 1.9394282e+03 1.00e+00 4.41e+02  -4.7 3.84e+02  -4.2 4.02e-03 1.77e-03f  1
#  409r 1.9390345e+03 1.00e+00 5.34e+02  -4.7 1.22e+02  -3.8 5.63e-02 2.19e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  410r 1.9380712e+03 1.00e+00 5.27e+02  -4.7 4.99e+01  -3.4 3.89e-03 5.84e-03f  1
#  411r 1.9369310e+03 1.00e+00 5.00e+02  -4.7 1.32e+02  -3.9 1.84e-03 1.13e-02f  1
#  412r 1.9303246e+03 1.00e+00 4.23e+02  -4.7 5.49e+01  -3.4 3.15e-03 4.42e-02f  1
#  413r 1.9283254e+03 1.00e+00 4.02e+02  -4.7 1.47e+02  -3.9 8.33e-03 2.15e-02f  1
#  414r 1.9243880e+03 1.00e+00 4.01e+02  -4.7 5.87e+01  -3.5 4.55e-02 2.76e-02f  1
#  415r 1.9201964e+03 1.00e+00 3.83e+02  -4.7 1.68e+02  -4.0 9.32e-03 4.51e-02f  1
#  416r 1.9078123e+03 1.00e+00 3.48e+02  -4.7 6.58e+01  -3.5 3.98e-02 9.12e-02f  1
#  417r 1.9066507e+03 1.00e+00 3.43e+02  -4.7 1.89e+02  -4.0 2.33e-02 1.63e-02f  1
#  418r 1.9036418e+03 1.00e+00 3.34e+02  -4.7 7.33e+01  -3.6 6.94e-02 2.43e-02f  1
#  419r 1.9029549e+03 1.00e+00 3.32e+02  -4.7 2.03e+02  -4.1 3.94e-02 5.42e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  420r 1.8979249e+03 1.00e+00 5.23e+02  -4.7 7.69e+01  -3.6 1.35e-01 2.95e-02f  1
#  421r 1.8952743e+03 1.00e+00 6.09e+02  -4.7 2.22e+02  -4.1 4.81e-02 1.38e-02f  1
#  422r 1.8756947e+03 1.00e+00 4.82e+02  -4.7 8.42e+01  -3.7 2.39e-02 1.09e-01f  1
#  423r 1.8736362e+03 1.00e+00 4.71e+02  -4.7 2.20e+02  -4.2 3.09e-02 2.29e-02f  1
#  424r 1.8632979e+03 1.00e+00 4.40e+02  -4.7 8.64e+01  -3.7 1.45e-01 6.25e-02f  1
#  425r 1.8515195e+03 1.00e+00 4.08e+02  -4.7 3.35e+01  -3.3 6.65e-02 7.19e-02f  1
#  426r 1.8493243e+03 1.00e+00 5.14e+02  -4.7 1.38e+00  -2.0 3.06e-01 4.19e-02f  1
#  427r 1.8436176e+03 1.00e+00 5.36e+02  -4.7 3.52e+00  -2.5 1.90e-01 5.46e-02f  1
#  428r 1.8248665e+03 1.00e+00 3.53e+02  -4.7 1.39e+00  -2.0 2.84e-01 3.17e-01f  1
#  429r 1.8214046e+03 1.00e+00 3.96e+02  -4.7 3.10e+00  -2.5 2.89e-01 3.18e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  430r 1.7863235e+03 1.00e+00 2.90e+02  -4.7 9.22e+00  -3.0 8.63e-02 2.10e-01f  1
#  431r 1.7830775e+03 1.00e+00 3.10e+02  -4.7 2.68e+01  -3.5 1.09e-01 1.82e-02f  1
#  432r 1.7811223e+03 1.00e+00 3.55e+02  -4.7 1.03e+01  -3.0 1.93e-01 1.30e-02f  1
#  433r 1.7591892e+03 1.00e+00 5.03e+02  -4.7 3.94e+00  -2.6 4.88e-01 2.02e-01f  1
#  434r 1.7314220e+03 1.00e+00 4.25e+02  -4.7 1.15e+01  -3.1 2.21e-01 1.87e-01f  1
#  435r 1.7280897e+03 1.00e+00 4.42e+02  -4.7 3.27e+01  -3.6 5.64e-02 2.13e-02f  1
#  436r 1.7229233e+03 1.00e+00 4.22e+02  -4.7 9.11e+01  -4.0 1.18e-02 3.32e-02f  1
#  437r 1.7190230e+03 1.00e+00 7.18e+02  -4.7 4.76e+00  -2.7 3.49e-01 4.13e-02f  1
#  438r 1.7165188e+03 1.00e+00 8.00e+02  -4.7 1.26e+01  -3.2 2.20e-01 1.89e-02f  1
#  439r 1.6842714e+03 1.00e+00 6.28e+02  -4.7 4.74e+00  -2.8 5.39e-01 3.30e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  440r 1.6623561e+03 1.00e+00 4.99e+02  -4.7 1.40e+01  -3.2 5.59e-02 1.97e-01f  1
#  441r 1.6617775e+03 1.00e+00 4.76e+02  -4.7 4.08e+01  -3.7 9.15e-02 5.32e-03f  1
#  442r 1.6539580e+03 1.00e+00 4.38e+02  -4.7 1.57e+01  -3.3 1.21e-01 8.15e-02f  1
#  443r 1.6535064e+03 1.00e+00 4.39e+02  -4.7 3.23e+02  -3.8 5.99e-04 3.93e-03f  1
#  444r 1.6515557e+03 1.00e+00 4.39e+02  -4.7 1.26e+02  -4.3 3.92e-03 2.08e-02f  1
#  445r 1.6501122e+03 1.00e+00 4.05e+02  -4.7 1.29e+00  -2.0 2.56e-02 6.42e-02f  1
#  446r 1.6398653e+03 1.00e+00 2.91e+02  -4.7 2.51e+00  -2.5 5.03e-02 2.28e-01f  1
#  447r 1.6396084e+03 1.00e+00 2.89e+02  -4.7 7.49e+00  -3.0 2.72e-03 3.97e-03f  1
#  448r 1.6221055e+03 1.00e+00 1.99e+02  -4.7 2.82e+00  -2.5 6.73e-01 4.07e-01f  1
#  449r 1.6179160e+03 1.00e+00 2.10e+02  -4.7 8.41e+00  -3.0 4.13e-01 7.64e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  450r 1.6121362e+03 1.00e+00 1.84e+02  -4.7 2.47e+01  -3.5 6.79e-02 8.79e-02f  1
#  451r 1.6091658e+03 1.00e+00 1.63e+02  -4.7 7.02e+01  -4.0 2.45e-02 4.74e-02f  1
#  452r 1.6085189e+03 1.00e+00 1.58e+02  -4.7 1.82e+02  -4.5 1.25e-02 1.67e-02f  1
#  453r 1.6086822e+03 1.00e+00 1.59e+02  -4.7 3.83e+02  -4.9 1.02e-02 6.16e-03f  1
#  454r 1.6080937e+03 1.00e+00 5.57e+02  -4.7 1.41e+02  -4.5 4.00e-02 1.18e-02f  1
#  455r 1.6080658e+03 1.00e+00 5.26e+02  -4.7 3.46e+02  -5.0 6.71e-03 8.60e-03f  1
#  456r 1.6071703e+03 1.00e+00 6.36e+02  -4.7 1.49e+02  -4.6 3.52e-02 1.91e-02f  1
#  457r 1.6070157e+03 1.00e+00 5.78e+02  -4.7 3.78e+02  -5.0 9.56e-03 1.69e-02f  1
#  458r 1.6063539e+03 1.00e+00 5.70e+02  -4.7 1.54e+02  -4.6 3.13e-02 1.36e-02f  1
#  459r 1.6060388e+03 1.00e+00 5.65e+02  -4.7 3.96e+02  -5.1 1.60e-02 1.07e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  460r 1.6050471e+03 1.00e+00 5.54e+02  -4.7 1.60e+02  -4.7 4.72e-03 1.92e-02f  1
#  461r 1.6047340e+03 1.00e+00 5.50e+02  -4.7 4.45e+02  -5.1 1.18e-02 8.32e-03f  1
#  462r 1.6037805e+03 1.00e+00 5.39e+02  -4.7 1.66e+02  -4.7 3.73e-02 1.82e-02f  1
#  463r 1.6034608e+03 1.00e+00 5.35e+02  -4.7 4.90e+02  -5.2 3.41e-02 7.74e-03f  1
#  464r 1.6031812e+03 1.00e+00 5.33e+02  -4.7 1.78e+02  -4.8 9.76e-04 5.31e-03f  1
#  465r 1.6028574e+03 1.00e+00 5.29e+02  -4.7 5.52e+02  -5.2 3.53e-03 7.36e-03f  1
#  466r 1.6026066e+03 1.00e+00 5.47e+02  -4.7 1.88e+02  -4.8 9.53e-02 4.81e-03f  1
#  467r 1.6019799e+03 1.00e+00 5.46e+02  -4.7 6.00e+02  -5.3 4.38e-02 1.60e-02f  1
#  468r 1.6007622e+03 1.00e+00 5.69e+02  -4.7 1.92e+02  -4.9 1.35e-01 2.47e-02f  1
#  469r 1.6005546e+03 1.00e+00 6.99e+02  -4.7 5.64e+02  -5.3 4.97e-02 7.64e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  470r 1.5988286e+03 1.00e+00 6.76e+02  -4.7 2.01e+02  -4.9 4.04e-02 3.79e-02f  1
#  471r 1.5984596e+03 1.00e+00 6.89e+02  -4.7 4.65e+02  -5.4 2.63e-02 1.80e-02f  1
#  472r 1.5976256e+03 1.00e+00 8.44e+02  -4.7 2.01e+02  -5.0 1.09e-01 2.09e-02f  1
#  473r 1.5975497e+03 1.00e+00 9.68e+02  -4.7 3.38e+02  -5.4 6.82e-02 2.61e-02f  1
#  474r 1.5966484e+03 1.00e+00 9.44e+02  -4.7 1.96e+02  -5.0 4.45e-02 2.95e-02f  1
#  475r 1.5966413e+03 1.00e+00 9.28e+02  -4.7 2.93e+02  -5.5 4.18e-02 2.05e-02f  1
#  476r 1.5960903e+03 1.00e+00 9.10e+02  -4.7 1.92e+02  -5.1 1.03e-01 1.90e-02f  1
#  477r 1.5952463e+03 1.00e+00 8.78e+02  -4.7 2.74e+02  -5.5 2.28e-02 3.30e-02f  1
#  478r 1.5943874e+03 1.00e+00 8.66e+02  -4.7 1.78e+02  -5.1 5.97e-02 2.16e-02f  1
#  479r 1.5940263e+03 1.00e+00 8.54e+02  -4.7 3.48e+02  -5.6 2.52e-02 2.11e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  480r 1.5930003e+03 1.00e+00 8.45e+02  -4.7 1.68e+02  -5.2 4.97e-02 3.09e-02f  1
#  481r 1.5934490e+03 1.00e+00 7.92e+02  -4.7 6.68e+02  -5.6 1.19e-02 2.87e-02f  1
#  482r 1.5931667e+03 1.00e+00 7.82e+02  -4.7 1.70e+02  -5.2 7.37e-03 1.22e-02f  1
#  483r 1.5924867e+03 1.00e+00 7.83e+02  -4.7 1.08e+02  -4.8 9.44e-02 2.06e-02f  1
#  484r 1.5916243e+03 1.00e+00 7.34e+02  -4.7 1.72e+02  -5.3 3.99e-02 4.19e-02f  1
#  485r 1.5907616e+03 1.00e+00 7.28e+02  -4.7 1.08e+02  -4.8 4.84e-02 2.95e-02h  1
#  486r 1.5905379e+03 1.00e+00 7.19e+02  -4.7 1.70e+02  -5.3 8.03e-02 1.33e-02h  1
#  487r 1.5890112e+03 1.00e+00 6.73e+02  -4.7 1.11e+02  -4.9 1.74e-01 5.66e-02f  1
#  488r 1.5885391e+03 1.00e+00 6.44e+02  -4.7 1.67e+02  -5.4 5.10e-02 4.43e-02f  1
#  489r 1.5880673e+03 1.00e+00 6.72e+02  -4.7 1.02e+02  -5.0 1.41e-01 2.20e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  490r 1.5878835e+03 1.00e+00 6.17e+02  -4.7 1.44e+02  -5.4 8.88e-03 2.24e-02h  1
#  491r 1.5878217e+03 1.00e+00 6.15e+02  -4.7 7.13e+01  -5.0 2.22e-02 3.19e-03h  1
#  492r 1.5877078e+03 1.00e+00 6.05e+02  -4.7 1.52e+02  -5.5 1.85e-02 1.66e-02h  1
#  493r 1.5866071e+03 1.00e+00 6.55e+02  -4.7 7.72e+01  -5.1 9.14e-03 6.15e-02f  1
#  494r 1.5865075e+03 1.00e+00 5.59e+02  -4.7 1.58e+02  -5.5 3.32e-02 1.56e-02h  1
#  495r 1.5854357e+03 1.00e+00 5.47e+02  -4.7 1.08e+02  -5.1 2.87e-03 4.83e-02h  1
#  496r 1.5854077e+03 1.00e+00 5.31e+02  -4.7 1.67e+02  -5.6 7.98e-02 2.56e-03h  1
#  497r 1.5836187e+03 1.00e+00 4.84e+02  -4.7 8.30e+01  -5.2 5.13e-02 8.85e-02h  1
#  498r 1.5831837e+03 1.00e+00 4.94e+02  -4.7 1.74e+02  -5.6 2.50e-01 5.91e-02h  1
#  499r 1.5820275e+03 1.00e+00 4.33e+02  -4.7 7.93e+01  -5.2 2.38e-02 7.42e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  500r 1.5819847e+03 1.00e+00 4.57e+02  -4.7 1.62e+02  -5.7 7.13e-02 9.58e-03h  1
#  501r 1.5809300e+03 1.00e+00 5.71e+02  -4.7 7.87e+01  -5.3 3.19e-01 8.06e-02f  1
#  502r 1.5807539e+03 1.00e+00 5.71e+02  -4.7 1.63e+02  -5.7 1.15e-01 6.64e-02h  1
#  503r 1.5797944e+03 1.00e+00 6.57e+02  -4.7 7.61e+01  -5.3 3.41e-01 9.94e-02h  1
#  504r 1.5797474e+03 1.00e+00 6.11e+02  -4.7 1.49e+02  -5.8 2.26e-01 1.32e-01h  1
#  505r 1.5790655e+03 1.00e+00 5.69e+02  -4.7 7.14e+01  -5.4 2.45e-01 1.20e-01h  1
#  506r 1.5792912e+03 1.00e+00 4.74e+02  -4.7 1.66e+02  -5.8 6.08e-02 1.38e-01h  1
#  507r 1.5791164e+03 1.00e+00 4.55e+02  -4.7 6.53e+01  -5.4 1.24e-01 5.92e-02h  1
#  508r 1.5790851e+03 1.00e+00 4.20e+02  -4.7 3.19e+02  -5.9 9.48e-03 5.78e-02h  1
#  509r 1.5790020e+03 1.00e+00 4.20e+02  -4.7 6.48e+01  -5.5 1.73e-01 4.01e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  510r 1.5787411e+03 1.00e+00 4.08e+02  -4.7 8.72e+02  -5.9 2.41e-03 1.70e-02h  1
#  511r 1.5786413e+03 1.00e+00 3.95e+02  -4.7 6.66e+01  -5.5 3.91e-02 3.32e-02h  1
#  512r 1.5776552e+03 1.00e+00 3.37e+02  -4.7 3.68e+01  -5.1 3.43e-01 1.86e-01h  1
#  513r 1.5775230e+03 1.00e+00 3.14e+02  -4.7 6.55e+01  -5.6 5.08e-02 6.63e-02h  1
#  514r 1.5763026e+03 1.00e+00 1.81e+02  -4.7 3.65e+01  -5.1 1.69e-01 3.93e-01h  1
#  515r 1.5762101e+03 1.00e+00 1.54e+02  -4.7 6.28e+01  -5.6 1.04e-01 1.48e-01h  1
#  516r 1.5760264e+03 1.00e+00 1.19e+02  -4.7 3.18e+01  -5.2 3.88e-01 2.37e-01h  1
#  517r 1.5756510e+03 1.00e+00 1.04e+02  -4.7 8.30e+01  -5.7 3.52e-02 1.65e-01h  1
#  518r 1.5751989e+03 1.00e+00 9.90e+01  -4.7 4.25e+04  -6.1 3.63e-04 1.43e-04f  1
#  519r 1.5743464e+03 1.00e+00 6.79e+01  -4.7 9.81e+01  -5.7 3.24e-01 3.14e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  520r 1.5741078e+03 1.00e+00 1.24e+02  -4.7 4.73e+02  -6.2 4.39e-02 1.12e-02h  1
#  521r 1.5740604e+03 1.00e+00 1.86e+02  -4.7 8.89e+02    -  9.23e-03 9.02e-04h  1
# ...
#  717r 1.5102449e+03 1.00e+00 1.40e+03  -7.0 1.42e+02  -4.5 5.68e-03 1.38e-02f  1
#  718r 1.5102294e+03 1.00e+00 1.38e+03  -7.0 3.90e+01  -4.1 1.55e-02 1.31e-02h  1
#  719r 1.5102293e+03 1.00e+00 1.54e+03  -7.0 1.62e+01  -3.7 1.82e-01 6.41e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  720r 1.5101925e+03 1.00e+00 1.42e+03  -7.0 4.52e+01  -4.2 7.99e-03 7.19e-02f  1
#  721r 1.5101924e+03 1.00e+00 1.43e+03  -7.0 1.78e+01  -3.7 9.51e-02 2.39e-05h  1
#  722r 1.5102100e+03 1.00e+00 1.42e+03  -7.0 1.15e+02  -4.2 4.57e-03 6.73e-03h  1
#  723r 1.5101972e+03 1.00e+00 1.40e+03  -7.0 1.99e+01  -3.8 3.12e-02 1.43e-02f  1
#  724r 1.5101951e+03 1.00e+00 1.40e+03  -7.0 7.78e+00  -3.4 1.34e-02 3.37e-03h  1
#  725r 1.5101647e+03 1.00e+00 1.35e+03  -7.0 2.22e+01  -3.8 6.15e-02 3.21e-02f  1
#  726r 1.5100780e+03 1.00e+00 1.17e+03  -7.0 8.68e+00  -3.4 5.48e-02 1.32e-01h  1
#  727r 1.5100388e+03 1.00e+00 1.12e+03  -7.0 2.44e+01  -3.9 1.38e-01 5.05e-02h  1
#  728r 1.5100241e+03 1.00e+00 1.09e+03  -7.0 9.58e+00  -3.5 2.50e-01 2.39e-02h  1
#  729r 1.5099921e+03 1.00e+00 1.02e+03  -7.0 2.70e+01  -3.9 4.53e-02 6.25e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  730r 1.5099723e+03 1.00e+00 1.21e+03  -7.0 1.06e+01  -3.5 2.18e-03 4.30e-02f  1
#  731r 1.5099824e+03 1.00e+00 1.13e+03  -7.0 3.22e+01  -4.0 6.80e-02 2.80e-02h  1
#  732r 1.5099819e+03 1.00e+00 1.24e+03  -7.0 1.18e+01  -3.6 2.47e-01 1.20e-03h  1
#  733r 1.5100497e+03 1.00e+00 1.16e+03  -7.0 4.12e+01  -4.0 4.14e-02 6.55e-02h  1
#  734r 1.5100244e+03 1.00e+00 1.02e+03  -7.0 1.32e+01  -3.6 2.45e-01 8.45e-02h  1
#  735r 1.5101069e+03 1.00e+00 9.89e+02  -7.0 6.95e+01  -4.1 2.81e-02 2.62e-02h  1
#  736r 1.5101013e+03 1.00e+00 9.04e+02  -7.0 1.48e+01  -3.7 2.11e-01 4.48e-02h  1
#  737r 1.5101717e+03 1.00e+00 8.80e+02  -7.0 2.13e+02  -4.1 1.04e-02 5.47e-03h  1
#  738r 1.5101811e+03 1.00e+00 8.06e+02  -7.0 1.72e+01  -3.7 7.17e-02 9.06e-02h  1
#  739r 1.5101772e+03 1.00e+00 7.72e+02  -7.0 6.42e+00  -3.3 1.01e-01 2.50e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  740r 1.5101890e+03 1.00e+00 7.40e+02  -7.0 2.05e+01  -3.8 5.44e-02 3.13e-02h  1
#  741r 1.5101814e+03 1.00e+00 6.33e+02  -7.0 7.21e+00  -3.3 4.38e-01 6.09e-02f  1
#  742r 1.5102378e+03 1.00e+00 5.92e+02  -7.0 2.46e+01  -3.8 5.75e-02 8.22e-02h  1
#  743r 1.5102253e+03 1.00e+00 4.96e+02  -7.0 8.09e+00  -3.4 2.92e-01 1.36e-01h  1
#  744r 1.5102645e+03 1.00e+00 4.91e+02  -7.0 3.19e+01  -3.9 1.53e-02 3.22e-02h  1
#  745r 1.5102646e+03 1.00e+00 4.37e+02  -7.0 9.27e+00  -3.4 2.48e-01 1.77e-02h  1
#  746r 1.5103418e+03 1.00e+00 4.41e+02  -7.0 4.11e+01  -3.9 2.35e-02 4.06e-02f  1
#  747r 1.5103419e+03 1.00e+00 3.79e+02  -7.0 1.09e+01  -3.5 2.22e-01 5.05e-04h  1
#  748r 1.5103466e+03 1.00e+00 4.59e+02  -7.0 5.91e+01  -4.0 3.88e-02 1.46e-03h  1
#  749r 1.5103760e+03 1.00e+00 3.70e+02  -7.0 1.24e+01  -3.5 1.07e-01 1.78e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  750r 1.5104169e+03 1.00e+00 3.60e+02  -7.0 1.05e+02  -4.0 4.69e-03 6.01e-03h  1
#  751r 1.5104448e+03 1.00e+00 3.37e+02  -7.0 1.49e+01  -3.6 6.67e-02 6.33e-02f  1
#  752r 1.5105486e+03 1.00e+00 3.25e+02  -7.0 1.22e+03  -4.1 1.43e-04 1.19e-03f  1
#  753r 1.5105522e+03 1.00e+00 3.20e+02  -7.0 1.84e+01  -3.6 4.37e-02 5.25e-03f  1
#  754r 1.5105559e+03 1.00e+00 2.67e+02  -7.0 5.94e+00  -3.2 4.78e-01 6.56e-02f  1
#  755r 1.5105559e+03 1.00e+00 2.89e+02  -7.0 2.18e+01  -3.7 1.03e-01 3.07e-05h  1
#  756r 1.5105671e+03 1.00e+00 2.34e+02  -7.0 6.76e+00  -3.3 2.43e-02 1.35e-01f  1
#  757r 1.5105672e+03 1.00e+00 2.36e+02  -7.0 2.65e+01  -3.7 4.60e-02 4.14e-05h  1
#  758r 1.5105951e+03 1.00e+00 2.12e+02  -7.0 7.75e+00  -3.3 2.93e-01 1.95e-01f  1
#  759r 1.5105961e+03 1.00e+00 2.20e+02  -7.0 3.33e+01  -3.8 4.60e-02 5.35e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  760r 1.5106135e+03 1.00e+00 2.15e+02  -7.0 8.96e+00  -3.4 1.46e-01 7.30e-02f  1
#  761r 1.5106572e+03 1.00e+00 2.10e+02  -7.0 4.29e+01  -3.8 5.47e-03 1.66e-02f  1
#  762r 1.5106997e+03 1.00e+00 1.85e+02  -7.0 1.04e+01  -3.4 1.33e-01 1.24e-01f  1
#  763r 1.5108123e+03 1.00e+00 1.78e+02  -7.0 6.25e+01  -3.9 7.31e-03 2.63e-02f  1
#  764r 1.5108219e+03 1.00e+00 2.11e+02  -7.0 1.25e+01  -3.5 3.20e-01 1.78e-02h  1
#  765r 1.5109280e+03 1.00e+00 2.08e+02  -7.0 1.18e+02  -3.9 1.16e-02 1.19e-02f  1
#  766r 1.5109283e+03 1.00e+00 2.19e+02  -7.0 1.12e+01  -3.5 1.32e-01 4.42e-04h  1
#  767r 1.5110767e+03 1.00e+00 2.16e+02  -7.0 2.15e+02  -4.0 7.95e-04 7.89e-03f  1
#  768r 1.5111596e+03 1.00e+00 2.00e+02  -7.0 1.27e+01  -3.6 8.05e-02 7.41e-02f  1
#  769r 1.5112176e+03 1.00e+00 1.67e+02  -7.0 4.67e+00  -3.1 3.06e-01 2.02e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  770r 1.5113246e+03 1.00e+00 1.57e+02  -7.0 1.44e+01  -3.6 1.26e-01 7.47e-02f  1
#  771r 1.5113250e+03 1.00e+00 2.34e+02  -7.0 5.29e+00  -3.2 3.92e-01 9.94e-04h  1
#  772r 1.5118582e+03 1.00e+00 1.71e+02  -7.0 4.32e+01  -3.7 1.70e-02 1.03e-01f  1
#  773r 1.5119944e+03 1.00e+00 1.67e+02  -7.0 4.79e+01  -4.2 8.45e-02 5.60e-02f  1
#  774r 1.5120604e+03 1.00e+00 1.66e+02  -7.0 1.45e+02  -4.6 2.69e-03 3.24e-03f  1
#  775r 1.5120707e+03 1.00e+00 1.81e+02  -7.0 5.43e+01  -4.2 8.97e-02 4.33e-03h  1
#  776r 1.5121985e+03 1.00e+00 1.80e+02  -7.0 5.12e+02  -4.7 8.46e-04 2.47e-03f  1
#  777r 1.5122010e+03 1.00e+00 2.18e+02  -7.0 6.11e+01  -4.3 2.09e-01 1.03e-03h  1
#  778r 1.5122387e+03 1.00e+00 2.33e+02  -7.0 1.20e+02  -4.7 9.38e-02 5.73e-03f  1
#  779r 1.5122648e+03 1.00e+00 2.43e+02  -7.0 1.87e+02  -5.2 5.59e-02 5.10e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  780r 1.5123072e+03 1.00e+00 2.45e+02  -7.0 8.91e+01  -4.8 3.72e-02 9.36e-03f  1
#  781r 1.5123767e+03 1.00e+00 2.42e+02  -7.0 1.93e+02  -5.3 1.23e-03 6.68e-03f  1
#  782r 1.5124575e+03 1.00e+00 2.38e+02  -7.0 9.49e+01  -4.8 5.47e-03 1.28e-02f  1
#  783r 1.5124843e+03 1.00e+00 2.39e+02  -7.0 2.29e+02  -5.3 7.91e-03 1.82e-03f  1
#  784r 1.5124988e+03 1.00e+00 2.42e+02  -7.0 8.79e+01  -4.9 2.09e-02 1.89e-03h  1
#  785r 1.5133661e+03 1.00e+00 2.41e+02  -7.0 2.03e+03  -4.5 7.60e-03 5.60e-03f  1
#  786r 1.5133774e+03 1.00e+00 2.59e+02  -7.0 1.59e+01  -4.0 1.41e-01 5.67e-03f  1
#  787r 1.5134347e+03 1.00e+00 2.85e+02  -7.0 5.27e+00  -3.6 3.49e-01 9.98e-02h  1
#  788r 1.5134349e+03 1.00e+00 3.25e+02  -7.0 1.91e+01  -4.1 1.98e-01 8.34e-05h  1
#  789r 1.5135298e+03 1.00e+00 2.62e+02  -7.0 5.92e+00  -3.7 2.50e-02 1.41e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  790r 1.5135298e+03 1.00e+00 3.10e+02  -7.0 2.38e+01  -4.1 2.35e-01 9.87e-06h  1
#  791r 1.5136498e+03 1.00e+00 2.46e+02  -7.0 6.68e+00  -3.7 5.44e-02 1.54e-01f  1
#  792r 1.5136504e+03 1.00e+00 2.59e+02  -7.0 3.11e+01  -4.2 6.52e-02 1.50e-04h  1
#  793r 1.5137051e+03 1.00e+00 3.04e+02  -7.0 7.56e+00  -3.8 4.54e-01 5.84e-02f  1
#  794r 1.5137229e+03 1.00e+00 3.04e+02  -7.0 4.49e+01  -4.2 8.25e-03 3.18e-03h  1
#  795r 1.5137267e+03 1.00e+00 3.19e+02  -7.0 8.60e+00  -3.8 1.59e-01 3.48e-03h  1
#  796r 1.5149230e+03 1.00e+00 2.70e+02  -7.0 8.24e+01  -4.3 4.26e-02 1.24e-01f  1
#  797r 1.5149596e+03 1.00e+00 2.68e+02  -7.0 1.43e+01  -3.9 4.50e-02 1.73e-02h  1
#  798r 1.5149979e+03 1.00e+00 2.77e+02  -7.0 4.55e+00  -3.4 3.15e-01 5.66e-02f  1
#  799r 1.5153057e+03 1.00e+00 2.38e+02  -7.0 1.71e+01  -3.9 8.47e-02 1.21e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  800r 1.5153489e+03 1.00e+00 2.66e+02  -7.0 5.41e+00  -3.5 2.90e-01 5.37e-02f  1
#  801r 1.5154766e+03 1.00e+00 2.70e+02  -7.0 2.23e+01  -4.0 1.35e-01 3.76e-02h  1
#  802r 1.5156457e+03 1.00e+00 3.37e+02  -7.0 6.31e+00  -3.5 1.00e+00 1.79e-01h  1
#  803r 1.5157300e+03 1.00e+00 3.33e+02  -7.0 3.00e+01  -4.0 1.20e-01 1.80e-02h  1
#  804r 1.5157621e+03 1.00e+00 3.48e+02  -7.0 7.42e+00  -3.6 3.85e-01 2.81e-02h  1
#  805r 1.5161671e+03 1.00e+00 3.30e+02  -7.0 4.14e+01  -4.1 9.56e-02 6.20e-02h  1
#  806r 1.5161955e+03 1.00e+00 4.13e+02  -7.0 9.16e+00  -3.6 5.99e-01 1.91e-02h  1
#  807r 1.5161991e+03 1.00e+00 4.31e+02  -7.0 8.20e+01  -4.1 7.94e-02 2.66e-04h  1
#  808r 1.5162086e+03 1.00e+00 5.12e+02  -7.0 1.06e+01  -3.7 4.87e-01 5.46e-03f  1
#  809r 1.5173778e+03 1.00e+00 4.89e+02  -7.0 2.09e+02  -4.2 4.65e-03 3.41e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  810r 1.5174170e+03 1.00e+00 4.95e+02  -7.0 1.61e+01  -3.7 1.41e-01 1.22e-02h  1
#  811r 1.5174216e+03 1.00e+00 4.93e+02  -7.0 3.96e+00  -3.3 1.39e-02 5.82e-03h  1
#  812r 1.5175370e+03 1.00e+00 4.84e+02  -7.0 1.95e+01  -3.8 9.27e-02 2.94e-02h  1
#  813r 1.5176119e+03 1.00e+00 5.63e+02  -7.0 5.09e+00  -3.4 2.76e-03 7.32e-02h  1
#  814r 1.5180409e+03 1.00e+00 6.23e+02  -7.0 2.45e+01  -3.8 6.72e-03 8.54e-02h  1
#  815r 1.5182086e+03 1.00e+00 5.32e+02  -7.0 6.72e+00  -3.4 1.83e-01 1.19e-01h  1
#  816r 1.5183470e+03 1.00e+00 5.16e+02  -7.0 3.53e+01  -3.9 4.70e-02 1.78e-02h  1
#  817r 1.5183472e+03 1.00e+00 4.89e+02  -7.0 5.66e+01  -4.4 6.34e-02 2.30e-05h  1
#  818r 1.5184138e+03 1.00e+00 4.38e+02  -7.0 1.58e+02  -4.9 3.47e-02 5.57e-03f  1
#  819r 1.5184469e+03 1.00e+00 3.57e+02  -7.0 3.11e+02  -5.3 6.14e-03 1.81e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  820r 1.5185996e+03 1.00e+00 5.61e+02  -7.0 1.49e+02  -4.9 2.58e-03 1.39e-02f  1
#  821r 1.5186540e+03 1.00e+00 5.59e+02  -7.0 3.32e+02  -5.4 2.84e-03 2.84e-03h  1
#  822r 1.5186579e+03 1.00e+00 4.31e+02  -7.0 1.64e+02  -5.0 5.18e-03 3.30e-04h  1
#  823r 1.5187660e+03 1.00e+00 4.30e+02  -7.0 4.86e+02  -5.4 3.23e-03 3.91e-03f  1
#  824r 1.5187918e+03 1.00e+00 3.80e+02  -7.0 1.89e+02  -5.0 4.59e-03 1.94e-03h  1
#  825r 1.5188087e+03 1.00e+00 5.63e+02  -7.0 3.44e+02  -5.5 1.66e-02 8.62e-04h  1
#  826r 1.5188151e+03 1.00e+00 5.39e+02  -7.0 1.10e+02  -5.1 4.30e-02 2.83e-03h  1
#  827r 1.5188239e+03 1.00e+00 5.38e+02  -7.0 3.83e+02  -5.5 2.00e-02 3.96e-03h  1
#  828r 1.5188279e+03 1.00e+00 4.77e+02  -7.0 1.19e+02  -5.1 3.14e-01 2.01e-03h  1
#  829r 1.5188662e+03 1.00e+00 6.73e+02  -7.0 5.84e+00  -3.8 8.26e-01 1.39e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  830r 1.5189393e+03 1.00e+00 6.28e+02  -7.0 1.62e+01  -4.3 1.77e-01 7.54e-02h  1
#  831r 1.5191328e+03 1.00e+00 5.61e+02  -7.0 1.97e+01  -4.7 6.79e-03 1.02e-01h  1
#  832r 1.5191791e+03 1.00e+00 5.53e+02  -7.0 4.49e+01  -5.2 1.30e-01 1.97e-02h  1
#  833r 1.5191803e+03 1.00e+00 4.49e+02  -7.0 1.11e+00  -3.0 3.74e-01 2.60e-01f  1
#  834r 1.5192450e+03 1.00e+00 2.22e+02  -7.0 1.90e+00  -3.5 2.13e-02 5.40e-01f  1
#  835r 1.5196671e+03 1.00e+00 2.21e+02  -7.0 2.69e+02    -  9.20e-03 7.45e-03h  1
#  836r 1.5196915e+03 1.00e+00 8.70e+01  -7.0 7.10e-01  -3.0 5.58e-01 6.08e-01f  1
#  837r 1.5218129e+03 1.00e+00 8.57e+01  -7.0 2.53e+02    -  9.44e-03 4.40e-02f  1
#  838r 1.5218210e+03 1.00e+00 7.51e+01  -7.0 1.91e+00  -3.5 1.19e-01 4.69e-02h  1
#  839r 1.5218236e+03 1.00e+00 1.57e+02  -7.0 7.35e-01  -3.1 2.98e-01 5.47e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  840r 1.5218446e+03 1.00e+00 1.14e+02  -7.0 2.10e+00  -3.6 3.14e-02 1.03e-01h  1
#  841r 1.5218577e+03 1.00e+00 6.38e+01  -7.0 8.15e-01  -3.1 7.51e-02 2.10e-01h  1
#  842r 1.5218730e+03 1.00e+00 5.93e+01  -7.0 2.24e+00  -3.6 7.50e-02 5.94e-02h  1
#  843r 1.5218899e+03 1.00e+00 2.55e+02  -7.0 8.85e-01  -3.2 8.69e-02 2.02e-01h  1
#  844r 1.5219734e+03 1.00e+00 2.63e+02  -7.0 2.47e+00  -3.7 1.19e-01 2.80e-01f  1
#  845r 1.5220120e+03 1.00e+00 2.66e+02  -7.0 2.73e+02    -  1.45e-02 9.44e-04h  1
#  846r 1.5224184e+03 1.00e+00 2.64e+02  -7.0 2.50e+02    -  1.16e-02 9.61e-03f  1
#  847r 1.5230108e+03 1.00e+00 2.88e+02  -7.0 2.50e+02    -  6.02e-02 1.39e-02h  1
#  848r 1.5234800e+03 1.00e+00 2.81e+02  -7.0 2.45e+02    -  3.71e-03 1.11e-02h  1
#  849r 1.5239942e+03 1.00e+00 2.83e+02  -7.0 2.43e+02    -  2.35e-02 1.24e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  850r 1.5250814e+03 1.00e+00 2.92e+02  -7.0 2.40e+02    -  4.85e-02 2.68e-02h  1
#  851r 1.5263374e+03 1.00e+00 3.80e+02  -7.0 2.33e+02    -  1.97e-01 3.25e-02h  1
#  852r 1.5291609e+03 1.00e+00 3.41e+02  -7.0 2.24e+02    -  3.34e-02 7.71e-02h  1
#  853r 1.5300779e+03 1.00e+00 3.42e+02  -7.0 2.08e+02    -  7.03e-02 2.89e-02h  1
#  854r 1.5310125e+03 1.00e+00 3.25e+02  -7.0 2.04e+02    -  6.06e-03 3.09e-02h  1
#  855r 1.5312560e+03 1.00e+00 3.30e+02  -7.0 1.95e+02    -  3.92e-02 8.45e-03h  1
#  856r 1.5313706e+03 1.00e+00 3.26e+02  -7.0 2.18e+02    -  3.53e-03 7.98e-03h  1
#  857r 1.5314262e+03 1.00e+00 3.42e+02  -7.0 2.04e+02    -  4.68e-02 3.85e-03h  1
#  858r 1.5321507e+03 1.00e+00 6.27e+02  -7.0 2.05e+02    -  2.30e-01 5.07e-02h  1
#  859r 1.5334891e+03 1.00e+00 6.40e+02  -7.0 2.10e+02    -  5.69e-03 9.98e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  860r 1.5349213e+03 1.00e+00 5.55e+02  -7.0 2.01e+02    -  6.19e-02 1.25e-01h  1
#  861r 1.5350389e+03 1.00e+00 5.49e+02  -7.0 1.75e+02    -  1.38e-02 1.20e-02h  1
#  862r 1.5351821e+03 1.00e+00 5.41e+02  -7.0 2.10e+02    -  9.31e-02 1.30e-02h  1
#  863r 1.5362331e+03 1.00e+00 4.89e+02  -7.0 2.05e+02    -  1.02e-01 9.72e-02h  1
#  864r 1.5363936e+03 1.00e+00 4.80e+02  -7.0 1.83e+02    -  2.42e-01 1.73e-02h  1
#  865r 1.5388363e+03 1.00e+00 3.77e+02  -7.0 1.92e+02    -  2.33e-02 2.14e-01h  1
#  866r 1.5391847e+03 1.00e+00 3.60e+02  -7.0 1.43e+02    -  1.00e-01 4.69e-02h  1
#  867r 1.5400514e+03 1.00e+00 3.16e+02  -7.0 1.35e+02    -  2.51e-01 1.21e-01h  1
#  868r 1.5419943e+03 1.00e+00 2.14e+02  -7.0 1.17e+02    -  8.27e-02 3.22e-01h  1
#  869r 1.5425401e+03 1.00e+00 1.82e+02  -7.0 7.77e+01    -  1.67e-02 1.50e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  870r 1.5427219e+03 1.00e+00 1.71e+02  -7.0 6.60e+01    -  5.61e-04 5.93e-02h  1
#  871r 1.5428958e+03 1.00e+00 1.61e+02  -7.0 6.20e+01    -  8.90e-02 6.16e-02f  1
#  872r 1.5432480e+03 1.00e+00 1.39e+02  -7.0 5.80e+01    -  1.11e-01 1.34e-01h  1
#  873r 1.5439024e+03 1.00e+00 1.03e+02  -7.0 4.99e+01    -  1.03e-01 2.93e-01h  1
#  874r 1.5441083e+03 1.00e+00 9.33e+01  -7.0 3.73e+01    -  1.96e-01 6.70e-01h  1
#  875r 1.5447037e+03 1.00e+00 1.02e+02  -7.0 2.02e+01    -  4.91e-02 3.98e-01h  1
#  876r 1.5447429e+03 1.00e+00 8.03e+01  -7.0 6.24e+00    -  2.43e-01 3.68e-01h  1
#  877r 1.5448178e+03 1.00e+00 9.46e+01  -7.0 4.04e+00    -  2.49e-03 1.00e+00f  1
#  878r 1.5448215e+03 1.00e+00 4.06e+01  -7.0 1.03e-01    -  5.71e-01 4.27e-01h  1
#  879r 1.5448284e+03 1.00e+00 2.37e+01  -7.0 1.12e-01    -  4.15e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  880r 1.5448355e+03 1.00e+00 8.94e+00  -7.0 6.35e-02    -  6.23e-01 1.00e+00h  1
#
# Number of Iterations....: 880
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5448360296253732e+03    1.5448360296253732e+03
# Dual infeasibility......:   9.9999996515305201e-01    9.9999996515305201e-01
# Constraint violation....:   9.9999999008737916e-01    9.9999999008737916e-01
# Variable bound violation:   9.9126208352728895e-09    9.9126208352728895e-09
# Complementarity.........:   9.5188702219082859e-08    9.5188702219082859e-08
# Overall NLP error.......:   9.9999999008737916e-01    9.9999999008737916e-01
#
#
# Number of objective function evaluations             = 925
# Number of objective gradient evaluations             = 334
# Number of equality constraint evaluations            = 925
# Number of inequality constraint evaluations          = 925
# Number of equality constraint Jacobian evaluations   = 883
# Number of inequality constraint Jacobian evaluations = 883
# Number of Lagrangian Hessian evaluations             = 881
# Total seconds in IPOPT                               = 464.047
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
#     model=unknown;
#         message from solver=Ipopt 3.14.4\x3a Converged to a locally infeasible
#         point. Problem may be infeasible.

# %%
#animate it
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as ani
from IPython.display import HTML
from matplotlib.animation import FuncAnimation, FFMpegWriter
import numpy as np
# %matplotlib inline
#matplotlib.use('WebAgg')

fig1, ax1 = plt.subplots(1,1) #create axes
ax1.set_aspect('equal')


ymax = np.max([m.q[n,p,'y'].value for n in range(1,N+1) for p in range(P+1)])
# time = [0]
# time.append(time[n-1]+hm*m.h[n].value)
# time.pop()

# ax.plot(time,m.GRF[n,'y'].value )

def plot_model(n,m,ax): #update function for animation
    ax.clear()
    ax.set_xlim([-2, 4])
    ax.set_ylim([-0.2, ymax + 0.2])
    ax.plot([-10,10],[0,0],linewidth=3,color='black')
    p = 0
    
    y = m.q[n,p,'y'].value
    x = m.q[n,p,'x'].value
    thb = (m.q[n,p,'th_b'].value)
    
    #plot body
    body_xb = x - 0.5*m.l['b']*cos(m.q[n,p,'th_b'].value)
    body_yb = y - 0.5*m.l['b']*sin(m.q[n,p,'th_b'].value)
    body_xf = x + 0.5*m.l['b']*cos(m.q[n,p,'th_b'].value)
    body_yf = y + 0.5*m.l['b']*sin(m.q[n,p,'th_b'].value)
    #ax.scatter([x],[y],s=50,color='black',zorder=50)
    ax.plot([body_xb,body_xf],[body_yb,body_yf],linewidth = 3,color='xkcd:black')

    shoulder_x = x + 0.06*cos(thb)
    shoulder_y = y + 0.06*sin(thb)

    hip_x = x - 0.06*cos(thb)
    hip_y = y - 0.06*sin(thb)
    
    cols = ['xkcd:bright pink','xkcd:bright blue']
    for li, leg in enumerate(legs):
        for si, s in enumerate(sides):
            if s == 'R':
                l1 = m.l['l1%s%s'%(s,leg)]
                th1 = m.q[n,p,'th_l1%s%s'%(s,leg)].value
                knee_x = shoulder_x+l1*np.sin(th1)
                knee_y = shoulder_y-l1*np.cos(th1)
                ax.plot([shoulder_x,knee_x],[shoulder_y,knee_y],color=cols[li])

                l2 = m.l['l2%s%s'%(s,leg)]
                th2 = m.q[n,p,'th_l2%s%s'%(s,leg)].value
                foot_x = knee_x + l2*np.sin(th2)
                foot_y = knee_y - l2*np.cos(th2)
                ax.plot([knee_x,foot_x],[knee_y,foot_y],color=cols[li])
            else:
                l1 = m.l['l1%s%s'%(s,leg)]
                th1 = m.q[n,p,'th_l1%s%s'%(s,leg)].value
                knee_x = hip_x+l1*np.sin(th1)
                knee_y = hip_y-l1*np.cos(th1)
                ax.plot([hip_x,knee_x],[hip_y,knee_y],color=cols[li])

                l2 = m.l['l2%s%s'%(s,leg)]
                th2 = m.q[n,p,'th_l2%s%s'%(s,leg)].value
                foot_x = knee_x + l2*np.sin(th2)
                foot_y = knee_y - l2*np.cos(th2)
                ax.plot([knee_x,foot_x],[knee_y,foot_y],color=cols[li])
        
       
update = lambda n: plot_model(n,m,ax1) #lambdify update function

animate = FuncAnimation(fig1,update,range(1,N+1),interval = 50,repeat=True)
HTML(animate.to_html5_video()) #you need to convert the animation to HTML5 to embed it in the notebook
writer = FFMpegWriter(fps=1.0/0.1, metadata=dict(artist='Me'))
animate.save('biped2_rad.mp4', writer=writer)

# %%
import pandas as pd


# Plotfig2, 
fig2, ax2 = plt.subplots(1,1)
time = [0]
for n in range(1,N+1): time.append(time[n-1] + hm*m.h[n].value)
time.pop()
dt = [m.h[n].value for n in range(1,N+1)]
m.h[1].value = 1.0 # left out of integrationtime_sum = hm*sum(model.h[n].value for n in nodes)
#print(f'Duration: {time_sum}s')
#ax2.plot(time, [m.GRF[n,'y'].value for n in m.N])
ax2.plot(time, [m.q[n,'th_b'].value for n in m.N])
ax2.set_xlabel('time')
ax2.set_ylabel('Angle [rad]')
ax2.set_title('Body Angle with virtual constraint')


# foot_pos = [m.footp[n,'y'].value - m.q[n,'y'].value for n in m.N]
# t = np.array(time)
# f = np.array(foot_pos)

# df = pd.DataFrame({"time":t, "foot-position":f}) 
# df.to_csv("monopodData.csv",index = False)
# Out:
# Text(0.5, 1.0, 'Body Angle with virtual constraint')
